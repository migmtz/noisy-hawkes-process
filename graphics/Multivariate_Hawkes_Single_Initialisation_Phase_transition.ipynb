# %%
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
from matplotlib import cm
from scipy import stats
from collections import deque
from scipy.optimize import minimize
from scipy.linalg import norm, inv, det, eig
import time
import seaborn as sns
import pickle
sns.set_theme()
np.set_printoptions(precision=2)

# %%
def fill_square_matrix(K):
    res = np.empty((K, K))
    for i in range(K):
        for j in range(K):
            val = input("%s %s" % (i + 1, j + 1))
            res[i, j] = val
    return res


def fill_column_vector(K):
    res = np.empty((K, 1))
    for i in range(K):
        val = input("%s 1" % (i + 1))
        res[i, 0] = val
    return res


class multivariate_exponential_hawkes(object):
    """
    Multivariate Hawkes process with exponential kernel. No events nor initial conditions considered.
    """

    def __init__(self, mu, alpha, beta, max_jumps=None, max_time=None):
        """

        Parameters
        ----------
        mu : array_like
            Baseline intensity vector. mu.shape[0] must coincide with shapes for alpha and beta.
        alpha : array_like
            Interaction factors matrix. Must be a square array with alpha.shape[0] coinciding with mu and beta.
        beta : array_like
            Decay factor matrix. Must be either an array. When corresponding to decay for each process i, it must
            be of shape (number_of_process, 1), or a square array. beta.shape[0] must coincide with mu and alpha.
        max_jumps : float, optional
            Maximal number of jumps. The default is None.
        max_time : float, optional
            Maximal time horizon. The default is None.

        Attributes
        ----------
        nb_processes : int
            Number of dimensions.
        timestamps : list of tuple (float, int)
            List of simulated events and their marks.
        intensity_jumps : array of float
            Array containing all intensities at each jump. It includes the baseline intensities mu.
        simulated : bool
            Parameter that marks if a process has been already been simulated,
            or if its event times have been initialized.

        """

        # We must begin by verifying that the process is a point process. In other words, that the number of
        # points in any bounded interval is a.s. finite. For this, we have to verify that the spectral radius of
        # the matrix alpha/beta (term by term) is <1.

        beta_radius = np.copy(beta)
        beta_radius[beta_radius == 0] = 1
        spectral_radius = np.max(np.abs(np.linalg.eig(np.abs(alpha) / beta_radius)[0]))

        if spectral_radius >= 1:
            # raise ValueError("Spectral radius is %s, which makes the process unstable." % (spectral_radius))
            warnings.warn("Spectral radius is %s, which makes the process unstable." % (spectral_radius),RuntimeWarning)
        self.mu = mu.reshape((alpha.shape[0], 1))
        self.alpha = alpha
        self.beta = beta
        self.max_jumps = max_jumps
        self.max_time = max_time

        self.nb_processes = self.mu.shape[0]
        self.count = np.zeros(self.nb_processes, dtype=int)

        self.timestamps = [(0.0, 0)]
        self.intensity_jumps = np.copy(mu)

        self.simulated = False

    def simulate(self):
        """
        Auxiliary function to check if already simulated and, if not, which simulation to launch.

        Simulation follows Ogata's adapted thinning algorithm. Upper bound obtained by the positive-part process.

        Works with both self-exciting and self-regulating processes.

        To launch simulation either self.max_jumps or self.max_time must be other than None, so the algorithm knows when to stop.
        """
        if not self.simulated:
            if self.max_jumps is not None and self.max_time is None:
                self.simulate_jumps()
            elif self.max_time is not None and self.max_jumps is None:
                self.simulate_time()
            else:
                print("Either max_jumps or max_time must be given.")
            self.simulated = True

        else:
            print("Process already simulated")

    def simulate_jumps(self):
        """
        Simulation is done until the maximal number of jumps (self.max_jumps) is attained.
        """
        flag = 0
        t = 0

        auxiliary_alpha = np.where(self.alpha > 0, self.alpha, 0)
        auxiliary_ij = np.zeros((self.nb_processes, self.nb_processes))
        auxiliary_intensity = np.copy(self.mu)

        ij_intensity = np.zeros((self.nb_processes, self.nb_processes))

        while flag < self.max_jumps:

            upper_intensity = np.sum(auxiliary_intensity)

            previous_t = t
            t += np.random.exponential(1 / upper_intensity)

            # ij_intensity = np.multiply(ij_intensity, np.exp(-self.beta * (t - self.timestamps[-1][0])))
            ij_intensity = np.multiply(ij_intensity, np.exp(-self.beta * (t - previous_t)))
            candidate_intensities = self.mu + np.sum(ij_intensity, axis=1, keepdims=True)
            pos_candidate = np.maximum(candidate_intensities, 0) / upper_intensity
            type_event = np.random.multinomial(1, np.concatenate((pos_candidate.squeeze(), np.array([0.0])))).argmax()
            if type_event < self.nb_processes:
                self.timestamps += [(t, type_event + 1)]
                ij_intensity[:, type_event] += self.alpha[:, type_event]
                self.intensity_jumps = np.c_[
                    self.intensity_jumps, self.mu + np.sum(ij_intensity, axis=1, keepdims=True)]

                auxiliary_ij = np.multiply(auxiliary_ij, np.exp(-self.beta * (t - self.timestamps[-2][0])))
                auxiliary_ij[:, type_event] += auxiliary_alpha[:, type_event]
                auxiliary_intensity = self.mu + np.sum(auxiliary_ij, axis=1, keepdims=True)

                flag += 1

                self.count[type_event] += 1

        self.max_time = self.timestamps[-1][0]
        # Important to add the max_time for plotting and being consistent.
        self.timestamps += [(self.max_time, 0)]

    def simulate_time(self):
        """
        Simulation is done for a window [0, T] (T = self.max_time) is attained.
        """
        t = 0
        flag = t < self.max_time

        auxiliary_alpha = np.where(self.alpha > 0, self.alpha, 0)
        auxiliary_ij = np.zeros((self.nb_processes, self.nb_processes))
        auxiliary_intensity = np.copy(self.mu)

        ij_intensity = np.zeros((self.nb_processes, self.nb_processes))

        while flag:

            upper_intensity = np.sum(auxiliary_intensity)

            previous_t = t
            t += np.random.exponential(1 / upper_intensity)

            # ij_intensity = np.multiply(ij_intensity, np.exp(-self.beta * (t - self.timestamps[-1][0])))
            ij_intensity = np.multiply(ij_intensity, np.exp(-self.beta * (t - previous_t)))
            candidate_intensities = self.mu + np.sum(ij_intensity, axis=1, keepdims=True)
            pos_candidate = np.maximum(candidate_intensities, 0) / upper_intensity
            type_event = np.random.multinomial(1,
                                               np.concatenate((pos_candidate.squeeze(), np.array([0.0])))).argmax()
            flag = t < self.max_time
            if type_event < self.nb_processes and flag:
                self.timestamps += [(t, type_event + 1)]
                ij_intensity[:, type_event] += self.alpha[:, type_event]
                self.intensity_jumps = np.c_[
                    self.intensity_jumps, self.mu + np.sum(ij_intensity, axis=1, keepdims=True)]

                auxiliary_ij = np.multiply(auxiliary_ij, np.exp(-self.beta * (t - self.timestamps[-2][0])))
                auxiliary_ij[:, type_event] += auxiliary_alpha[:, type_event]
                auxiliary_intensity = self.mu + np.sum(auxiliary_ij, axis=1, keepdims=True)

                self.count[type_event] += 1

        self.timestamps += [(self.max_time, 0)]

    def plot_intensity(self, ax=None, plot_N=True, where=10):
        """
        Plot intensity function. If plot_N is True, plots also step functions N^i([0,t]).
        The parameter ax allows to plot the intensity function in a previously created plot.

        Parameters
        ----------
        ax : array of Axes, optional.
            If None, method will generate own figure.
            Otherwise, will use given axes. Must be array of shape (2,K) if plot_N = True, or (K,) if plot_N = False
        plot_N : bool, optional.
            Whether we plot the step function N^i or not.
        """

        if not self.simulated:
            print("Simulate first")

        else:
            plt.rcParams['axes.grid'] = True
            if plot_N:
                jumps_plot = [[0] for i in range(self.nb_processes)]
                if ax is None:
                    fig, ax = plt.subplots(2, self.nb_processes, sharex=True)
                    ax1 = ax[0, :]
                    ax2 = ax[1, :]
                elif isinstance(ax[0,0], matplotlib.axes.Axes):
                    ax1 = ax[0, :]
                    ax2 = ax[1, :]
                else:
                    return "ax is the wrong shape. It should be (2, number of processes+1)"
            else:
                if ax is None:
                    fig, ax1 = plt.subplots(1, self.nb_processes)
                elif isinstance(ax, matplotlib.axes.Axes) or isinstance(ax, np.ndarray):
                    ax1 = ax
                else:
                    return "ax is the wrong shape. It should be (number of processes+1,)"

            times = [0, self.timestamps[1][0]]
            intensities = np.array([[self.mu[i, 0], self.mu[i, 0]] for i in range(self.nb_processes)])

            ij_intensity = np.zeros((self.nb_processes, self.nb_processes))

            step = 100
            # print("here", self.timestamps[len(self.timestamps)])

            for i in range(1, len(self.timestamps[1:where])):
                # On commence par mettre à jour la matrice lambda^{ij}
                ij_intensity = np.multiply(ij_intensity,
                                           np.exp(-self.beta * (self.timestamps[i][0] - self.timestamps[i - 1][0])))
                # On enregistre le saut d'intensité de l'évenement, pour son type.
                ij_intensity[:, self.timestamps[i][1]-1] += self.alpha[:, self.timestamps[i][1]-1]

                # On définit la fonction à tracer entre T_n et T_{n+1}
                func = lambda x: self.mu + np.matmul(
                    np.multiply(ij_intensity, np.exp(-self.beta * (x - self.timestamps[i][0]))),
                                np.ones((self.nb_processes, 1)))

                # On enregistre la division de temps et les sauts
                interval_t = np.linspace(self.timestamps[i][0], self.timestamps[i + 1][0], step)
                times += interval_t.tolist()

                intensities = np.concatenate((intensities, np.array(list(map(func, interval_t))).squeeze().T ), axis=1)
                if plot_N:
                    jumps_plot[self.timestamps[i][1]-1] += [self.timestamps[i][0] for t in range(2)]

            for i in range(self.nb_processes):
                ax1[i].plot(times, intensities[i], label="Underlying intensity", c="#1f77b4", linestyle="--")
                ax1[i].plot(times, np.maximum(intensities[i], 0), label="Conditional intensity", c='r')
                # ax1[i].plot([i for i,j in self.timestamps[:-1]], self.intensity_jumps[i,:], c='k', alpha=0.5)

            ax1[0].legend()

            if plot_N:
                for i in range(self.nb_processes):
                    jumps_plot[i] += [times[-1]]
                    ax2[i].plot(jumps_plot[i], [t for t in range(len(jumps_plot[i])//2) for j in range(2)], c="r", label="Process #%s"%(i+1))
                    # ax2[i].set_ylim(ax2[i].get_ylim())
                    for j in range(self.nb_processes):
                        if j != i:
                            ax2[j].plot(jumps_plot[i], [t for t in range(len(jumps_plot[i])//2) for j in range(2)], c="#1f77b4", alpha=0.5)

                    ax2[i].legend()

    def plot_heatmap(self, ax=None):
        """
        This function allows to observe the heatmap where each cell {ij} corresponds to the value {alpha/beta} from that interaction

        Parameters
        ----------
        ax : .axes.Axes, optional.
            If None, method will generate own ax.
            Otherwise, will use given ax.
        """
        import seaborn as sns

        if ax is None:
            fig, ax = plt.subplots()
        else:
            ax = ax
        beta_heat = np.copy(self.beta)
        beta_heat[beta_heat == 0] = 1
        heat_matrix = self.alpha/beta_heat

        hex_list = ['#FF3333', '#FFFFFF', '#33FF49']

        ax = sns.heatmap(heat_matrix, cmap=get_continuous_cmap(hex_list), center=0, ax=ax, annot=True)

# %%
# Periodogram and spectral functions for full matrix

def multivariate_periodogram(w, tList):
    max_time = tList[-1][0]
    dim = int(np.max(np.array(tList)[:, 1]))
    
    dimensional_times = [[t for t,i in tList if i == j] for j in range(1, dim+1)]
    
    J_w = np.array([np.sum([np.exp(2j * np.pi * w * t) for t in i]) for i in dimensional_times]).reshape((dim, 1))
    return (1/max_time) * J_w @ np.conj(J_w.T)


def multivariate_spectral_noised_density(w, theta):
    mu, alpha, beta, noise = theta
    dim = mu.shape[0]
    mean_matrix = np.identity(dim) * (inv(np.identity(dim) - alpha + 1e-12) @ mu)
    
    fourier_matrix = alpha * beta / (beta + 2j * np.pi * w)
    spectral_matrix = inv(np.identity(dim) - fourier_matrix)
    return np.conj(spectral_matrix) @ mean_matrix @ (spectral_matrix.T) + noise * np.identity(dim)


def spectral_multivariate_noised_ll(theta, periodogram, K, max_time):
    dim = int(np.sqrt(theta.shape[0]) - 1)
    theta_mid = theta[:-1]
    theta_aux = (theta_mid[:dim].reshape((dim, 1)), theta_mid[dim:-dim].reshape((dim, dim)), theta_mid[-dim:].reshape((dim, 1)), theta[-1])
    f_matrixes = [multivariate_spectral_noised_density(j/max_time, theta_aux) for j in range(1, K+1)]
    ll = np.sum([np.trace(inv(f_matrixes[i]) @ periodogram[i]) + np.log(det(f_matrixes[i])) for i in range(0, K)])
    return (1/max_time) * ll

# %%
#Spectral functions for reduced model
def multivariate_spectral_noised_single(w, theta):
    mu, alpha, beta, noise = theta
    #beta = np.array([beta_aux, 0]).reshape((2, 1))
    dim = mu.shape[0]
    m_1 = mu[0,0]
    m_2 = mu[1,0] + m_1 * alpha
    

    f_11 = m_1 + noise
    f_12 = m_1 * (alpha * beta)/(beta + 2j * np.pi * w)
    f_21 = m_1 * (alpha * beta)/(beta - 2j * np.pi * w)
    f_22 = m_1 * ((alpha * beta)**2)/(beta**2 + (2 * np.pi * w)**2) + m_2 + noise
    return np.array([[f_11, f_12], [f_21, f_22]])


def spectral_multivariate_noised_ll_single(theta, periodogram, K, max_time):
    dim = 2
    #theta_mid = theta[:-1]
    theta_aux = (np.array(theta[:dim]).reshape((dim, 1)), 
                 theta[dim], 
                 theta[dim+1], 
                 theta[-1])
    f_matrixes = [multivariate_spectral_noised_single(j/max_time, theta_aux) for j in range(1, K+1)]
    ll = np.sum([np.trace(inv(f_matrixes[i]) @ periodogram[i]) + np.log(det(f_matrixes[i])) for i in range(0, K)])
    return (1/max_time) * np.real(ll)

# %% [markdown]
# # Let's go!

# %%
mu = np.array([[1.0],
               [1.0]])
alpha = np.array([[0.0, 0.0],
                  [0.2, 0.0]])
beta = np.array([[1.0],
                 [1.3]])
noise = 0.5
dim = 2
print("Spectral radius:", norm(alpha, ord=2))
# Out:
# Spectral radius: 0.2

# %%
n_trials = 10

the_max_time = [100, 1000, 3000, 5000, 10000]
the_alpha0 = [0.2, 0.4, 0.6, 0.8]

pairs = np.array(np.meshgrid(the_max_time, the_alpha0)).T.reshape(-1, 2)
print(pairs.shape)
# Out:
# (20, 2)

# %%
from multiprocess import Pool, cpu_count

n_trials = 10

#the_max_time = [10000]
the_max_time = [100, 1000, 3000, 5000, 10000]
the_alpha0 = [0.2, 0.4, 0.6, 0.8]

pairs = np.array(np.meshgrid(the_max_time, the_alpha0)).T.reshape(-1, 2)

def job(t):
    ijob, pair = t
    np.random.seed(ijob+42 + trial*100)
    max_time, alpha0 = pair

    # Store results
    result = dict(max_time=max_time, alpha=alpha0)

    # Set variates
    alpha[1, 0] = alpha0
    
    # Simulation
    hp = multivariate_exponential_hawkes(mu, alpha * beta, beta, max_time=max_time)
    hp.simulate()
    hp_times = hp.timestamps
    
    pp = multivariate_exponential_hawkes(noise * np.ones((2,1)), 0*alpha, beta, max_time=max_time)
    pp.simulate()
    pp_times = pp.timestamps
    
    idx = np.argsort(pp_times[1:-1] + hp_times, axis=0)[:, 0]
    parasited_times = np.array(pp_times[1:-1] + hp_times)[idx]
    K = int(parasited_times.shape[0])

    # Periodogram computation            
    periodogram = [multivariate_periodogram(w, parasited_times) for w in np.arange(1, K+1)/max_time]
    
    # Optimization
    bounds = [(1e-16, None), (1e-16, None), (1e-16, 1-1e-16), (1e-16, None), (1e-16, None)]
    res = minimize(spectral_multivariate_noised_ll_single,
                   [.1]*5, tol=1e-16,
                   method="L-BFGS-B", jac=None,
                   args=(periodogram, K, max_time),
                   bounds=bounds, options={"disp":False})
    result['theta'] = res.x
    
    # Progress bar
    print('-', end='')

    return result

# Load previous results
results = []
#with open('results.pkl', 'rb') as fi:
#    results = pickle.load(fi)
# start_trial = max([res['trial'] for res in results]) + 1
start_trial = 0
print(f'Start at Trial {start_trial}')
print()

# Progress bar
n_jobs = (n_trials - start_trial) * pairs.shape[0]
print('|' + '-'*n_jobs + '|\n ', end='')
print("|")
for trial in range(start_trial, n_trials):
    # Do the job
    with Pool(cpu_count()-1) as p:
        res_pool = p.map(job, enumerate(pairs))

    # Add trial info
    for res in res_pool:
        res['trial'] = trial
    results += res_pool

    # Save
    with open('results0103N.pkl', 'wb') as fo:
        pickle.dump(results, fo)

print('\n Done')
# Out:
# Start at Trial 0
#
# |--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
#  --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  Done

# %%
|--------------------------------------------------------------------------------'
# Out:
# s s

# %%
print('|' + ' '*n_jobs +"|")
# Out:
# |                                                                                                                                                                                                        |

# %%
print('|' + ' '*n_jobs + '|\n ', end='')
# Out:
# |                                                                                                                                                                                                        |

# %%
with open('results.pkl', 'rb') as fi:
    pkl_results = pickle.load(fi)
#print(pkl_results)
counting = 0
for res in pkl_results:
    if res["max_time"] in [100, 1000, 3000, 5000, 10000]:
        counting += 1
    print(res["max_time"],res["alpha"], res["trial"])
print(counting)
# Out:
# 100.0 0.2 0
# 100.0 0.4 0
# 100.0 0.6 0
# 100.0 0.8 0
# 1000.0 0.2 0
# 1000.0 0.4 0
# 1000.0 0.6 0
# 1000.0 0.8 0
# 2000.0 0.2 0
# 2000.0 0.4 0
# 2000.0 0.6 0
# 2000.0 0.8 0
# 100.0 0.2 1
# 100.0 0.4 1
# 100.0 0.6 1
# 100.0 0.8 1
# 1000.0 0.2 1
# 1000.0 0.4 1
# 1000.0 0.6 1
# 1000.0 0.8 1
# 2000.0 0.2 1
# 2000.0 0.4 1
# 2000.0 0.6 1
# 2000.0 0.8 1
# 2500.0 0.2 0
# 2500.0 0.4 0
# 2500.0 0.6 0
# 2500.0 0.8 0
# 2500.0 0.2 1
# 2500.0 0.4 1
# 2500.0 0.6 1
# 2500.0 0.8 1
# 3000.0 0.2 0
# 3000.0 0.4 0
# 3000.0 0.6 0
# 3000.0 0.8 0
# 3500.0 0.2 0
# 3500.0 0.4 0
# 3500.0 0.6 0
# 3500.0 0.8 0
# 3000.0 0.2 1
# 3000.0 0.4 1
# 3000.0 0.6 1
# 3000.0 0.8 1
# 3500.0 0.2 1
# 3500.0 0.4 1
# 3500.0 0.6 1
# 3500.0 0.8 1
# 100.0 0.2 2
# 100.0 0.4 2
# 100.0 0.6 2
# 100.0 0.8 2
# 1000.0 0.2 2
# 1000.0 0.4 2
# 1000.0 0.6 2
# 1000.0 0.8 2
# 2000.0 0.2 2
# 2000.0 0.4 2
# 2000.0 0.6 2
# 2000.0 0.8 2
# 2500.0 0.2 2
# 2500.0 0.4 2
# 2500.0 0.6 2
# 2500.0 0.8 2
# 3000.0 0.2 2
# 3000.0 0.4 2
# 3000.0 0.6 2
# 3000.0 0.8 2
# 3500.0 0.2 2
# 3500.0 0.4 2
# 3500.0 0.6 2
# 3500.0 0.8 2
# 100.0 0.2 3
# 100.0 0.4 3
# 100.0 0.6 3
# 100.0 0.8 3
# 1000.0 0.2 3
# 1000.0 0.4 3
# 1000.0 0.6 3
# 1000.0 0.8 3
# 2000.0 0.2 3
# 2000.0 0.4 3
# 2000.0 0.6 3
# 2000.0 0.8 3
# 2500.0 0.2 3
# 2500.0 0.4 3
# 2500.0 0.6 3
# 2500.0 0.8 3
# 3000.0 0.2 3
# 3000.0 0.4 3
# 3000.0 0.6 3
# 3000.0 0.8 3
# 3500.0 0.2 3
# 3500.0 0.4 3
# 3500.0 0.6 3
# 3500.0 0.8 3
# 100.0 0.2 4
# 100.0 0.4 4
# 100.0 0.6 4
# 100.0 0.8 4
# 1000.0 0.2 4
# 1000.0 0.4 4
# 1000.0 0.6 4
# 1000.0 0.8 4
# 2000.0 0.2 4
# 2000.0 0.4 4
# 2000.0 0.6 4
# 2000.0 0.8 4
# 2500.0 0.2 4
# 2500.0 0.4 4
# 2500.0 0.6 4
# 2500.0 0.8 4
# 3000.0 0.2 4
# 3000.0 0.4 4
# 3000.0 0.6 4
# 3000.0 0.8 4
# 3500.0 0.2 4
# 3500.0 0.4 4
# 3500.0 0.6 4
# 3500.0 0.8 4
# 100.0 0.2 5
# 100.0 0.4 5
# 100.0 0.6 5
# 100.0 0.8 5
# 1000.0 0.2 5
# 1000.0 0.4 5
# 1000.0 0.6 5
# 1000.0 0.8 5
# 2000.0 0.2 5
# 2000.0 0.4 5
# 2000.0 0.6 5
# 2000.0 0.8 5
# 2500.0 0.2 5
# 2500.0 0.4 5
# 2500.0 0.6 5
# 2500.0 0.8 5
# 3000.0 0.2 5
# 3000.0 0.4 5
# 3000.0 0.6 5
# 3000.0 0.8 5
# 3500.0 0.2 5
# 3500.0 0.4 5
# 3500.0 0.6 5
# 3500.0 0.8 5
# 100.0 0.2 6
# 100.0 0.4 6
# 100.0 0.6 6
# 100.0 0.8 6
# 1000.0 0.2 6
# 1000.0 0.4 6
# 1000.0 0.6 6
# 1000.0 0.8 6
# 2000.0 0.2 6
# 2000.0 0.4 6
# 2000.0 0.6 6
# 2000.0 0.8 6
# 2500.0 0.2 6
# 2500.0 0.4 6
# 2500.0 0.6 6
# 2500.0 0.8 6
# 3000.0 0.2 6
# 3000.0 0.4 6
# 3000.0 0.6 6
# 3000.0 0.8 6
# 3500.0 0.2 6
# 3500.0 0.4 6
# 3500.0 0.6 6
# 3500.0 0.8 6
# 100.0 0.2 7
# 100.0 0.4 7
# 100.0 0.6 7
# 100.0 0.8 7
# 1000.0 0.2 7
# 1000.0 0.4 7
# 1000.0 0.6 7
# 1000.0 0.8 7
# 2000.0 0.2 7
# 2000.0 0.4 7
# 2000.0 0.6 7
# 2000.0 0.8 7
# 2500.0 0.2 7
# 2500.0 0.4 7
# 2500.0 0.6 7
# 2500.0 0.8 7
# 3000.0 0.2 7
# 3000.0 0.4 7
# 3000.0 0.6 7
# 3000.0 0.8 7
# 3500.0 0.2 7
# 3500.0 0.4 7
# 3500.0 0.6 7
# 3500.0 0.8 7
# 100.0 0.2 8
# 100.0 0.4 8
# 100.0 0.6 8
# 100.0 0.8 8
# 1000.0 0.2 8
# 1000.0 0.4 8
# 1000.0 0.6 8
# 1000.0 0.8 8
# 2000.0 0.2 8
# 2000.0 0.4 8
# 2000.0 0.6 8
# 2000.0 0.8 8
# 2500.0 0.2 8
# 2500.0 0.4 8
# 2500.0 0.6 8
# 2500.0 0.8 8
# 3000.0 0.2 8
# 3000.0 0.4 8
# 3000.0 0.6 8
# 3000.0 0.8 8
# 3500.0 0.2 8
# 3500.0 0.4 8
# 3500.0 0.6 8
# 3500.0 0.8 8
# 100.0 0.2 9
# 100.0 0.4 9
# 100.0 0.6 9
# 100.0 0.8 9
# 1000.0 0.2 9
# 1000.0 0.4 9
# 1000.0 0.6 9
# 1000.0 0.8 9
# 2000.0 0.2 9
# 2000.0 0.4 9
# 2000.0 0.6 9
# 2000.0 0.8 9
# 2500.0 0.2 9
# 2500.0 0.4 9
# 2500.0 0.6 9
# 2500.0 0.8 9
# 3000.0 0.2 9
# 3000.0 0.4 9
# 3000.0 0.6 9
# 3000.0 0.8 9
# 3500.0 0.2 9
# 3500.0 0.4 9
# 3500.0 0.6 9
# 3500.0 0.8 9
# 4000.0 0.2 0
# 4000.0 0.4 0
# 4000.0 0.6 0
# 4000.0 0.8 0
# 5000.0 0.2 0
# 5000.0 0.4 0
# 5000.0 0.6 0
# 5000.0 0.8 0
# 4000.0 0.2 1
# 4000.0 0.4 1
# 4000.0 0.6 1
# 4000.0 0.8 1
# 5000.0 0.2 1
# 5000.0 0.4 1
# 5000.0 0.6 1
# 5000.0 0.8 1
# 4000.0 0.2 2
# 4000.0 0.4 2
# 4000.0 0.6 2
# 4000.0 0.8 2
# 5000.0 0.2 2
# 5000.0 0.4 2
# 5000.0 0.6 2
# 5000.0 0.8 2
# 4000.0 0.2 3
# 4000.0 0.4 3
# 4000.0 0.6 3
# 4000.0 0.8 3
# 5000.0 0.2 3
# 5000.0 0.4 3
# 5000.0 0.6 3
# 5000.0 0.8 3
# 4000.0 0.2 4
# 4000.0 0.4 4
# 4000.0 0.6 4
# 4000.0 0.8 4
# 5000.0 0.2 4
# 5000.0 0.4 4
# 5000.0 0.6 4
# 5000.0 0.8 4
# 4000.0 0.2 5
# 4000.0 0.4 5
# 4000.0 0.6 5
# 4000.0 0.8 5
# 5000.0 0.2 5
# 5000.0 0.4 5
# 5000.0 0.6 5
# 5000.0 0.8 5
# 4000.0 0.2 6
# 4000.0 0.4 6
# 4000.0 0.6 6
# 4000.0 0.8 6
# 5000.0 0.2 6
# 5000.0 0.4 6
# 5000.0 0.6 6
# 5000.0 0.8 6
# 4000.0 0.2 7
# 4000.0 0.4 7
# 4000.0 0.6 7
# 4000.0 0.8 7
# 5000.0 0.2 7
# 5000.0 0.4 7
# 5000.0 0.6 7
# 5000.0 0.8 7
# 4000.0 0.2 8
# 4000.0 0.4 8
# 4000.0 0.6 8
# 4000.0 0.8 8
# 5000.0 0.2 8
# 5000.0 0.4 8
# 5000.0 0.6 8
# 5000.0 0.8 8
# 4000.0 0.2 9
# 4000.0 0.4 9
# 4000.0 0.6 9
# 4000.0 0.8 9
# 5000.0 0.2 9
# 5000.0 0.4 9
# 5000.0 0.6 9
# 5000.0 0.8 9
# 10000.0 0.2 0
# 10000.0 0.4 0
# 10000.0 0.6 0
# 10000.0 0.8 0
# 10000.0 0.2 1
# 10000.0 0.4 1
# 10000.0 0.6 1
# 10000.0 0.8 1
# 10000.0 0.2 2
# 10000.0 0.4 2
# 10000.0 0.6 2
# 10000.0 0.8 2
# 10000.0 0.2 3
# 10000.0 0.4 3
# 10000.0 0.6 3
# 10000.0 0.8 3
# 10000.0 0.2 4
# 10000.0 0.4 4
# 10000.0 0.6 4
# 10000.0 0.8 4
# 10000.0 0.2 5
# 10000.0 0.4 5
# 10000.0 0.6 5
# 10000.0 0.8 5
# 10000.0 0.2 6
# 10000.0 0.4 6
# 10000.0 0.6 6
# 10000.0 0.8 6
# 10000.0 0.2 7
# 10000.0 0.4 7
# 10000.0 0.6 7
# 10000.0 0.8 7
# 10000.0 0.2 8
# 10000.0 0.4 8
# 10000.0 0.6 8
# 10000.0 0.8 8
# 10000.0 0.2 9
# 10000.0 0.4 9
# 10000.0 0.6 9
# 10000.0 0.8 9
# 200

# %%
with open('results.pkl', 'rb') as fi:
    pkl_results = pickle.load(fi)

set_max_time = set()
set_alpha = set()
for res in pkl_results:
    set_max_time.add(res['max_time'])
    set_alpha.add(res['alpha'])
list_max_time = sorted(set_max_time, reverse=True)
list_alpha = sorted(set_alpha)

mat = np.zeros((len(list_max_time), len(list_alpha)))
err_mat = np.zeros_like(mat)
std_mat = np.zeros_like(mat)
n_mat = np.zeros_like(mat)
for i, max_time in enumerate(list_max_time):
    for j, alpha0 in enumerate(list_alpha):
        for res in pkl_results:
            if res['max_time'] == max_time and res['alpha'] == alpha0:
                mat[i, j] += res['theta'][-1]  # lambda0
                err_mat[i, j] += np.abs(noise - res['theta'][-1])  # Error on lambda0
                std_mat[i, j] += res['theta'][-1]**2
                n_mat[i, j] += 1
mat /= n_mat
err_mat /= n_mat
std_mat = np.sqrt(std_mat/n_mat - mat**2)

def plot_mat(m, title=''):
    plt.figure(figsize=(8,)*2)
    plt.imshow(m, cmap='Oranges')
    plt.colorbar()
    plt.grid(False)
    for i in range(m.shape[0]):
        for j in range(m.shape[1]):
            plt.text(j-.18, i, f'{m[i, j]:.2f}')
    plt.xticks(range(len(list_alpha)), labels=list_alpha)
    plt.yticks(range(len(list_max_time)), labels=list_max_time)
    plt.xlabel('alpha')
    plt.ylabel('max time')
    plt.title(title)

plot_mat(mat, 'lambda0')
plot_mat(std_mat, 'std lambda0')
plot_mat(err_mat, 'Error lambda0')

# %%
for i, max_time in enumerate(list_max_time):
    for j, alpha0 in enumerate(list_alpha):
        print(f'max time: {max_time} / alpha0: {alpha0}')
        for res in pkl_results:
            if res['max_time'] == max_time and res['alpha'] == alpha0:
                print('   ', res['theta'][-1])  # lambda0
# Out:
# max time: 10000.0 / alpha0: 0.2
#     1e-16
#     1.13042708945865
#     1.3418041843819046
#     1e-16
#     0.8746818235786916
#     0.9479054357205273
#     1e-16
# max time: 10000.0 / alpha0: 0.4
#     0.6670503276515252
#     0.7886359968667945
#     0.9408209120595361
#     0.5059172185816807
#     0.6033164356884516
#     1e-16
#     1e-16
# max time: 10000.0 / alpha0: 0.6
#     0.5563637671238508
#     0.6461027218391955
#     0.6642292015811859
#     0.6968601287442637
#     0.7864384584154062
#     0.5663809781194706
#     0.46015340930235393
# max time: 10000.0 / alpha0: 0.8
#     0.41182438967094276
#     0.5418046189257688
#     0.742632268020183
#     0.5191540682245563
#     0.4141604352938561
#     0.6198746343379492
#     0.7153048098130497
# max time: 5000.0 / alpha0: 0.2
#     1.324641183052168
#     1e-16
#     1e-16
#     1.2729153684463594
#     0.7252736484399128
#     0.6868887379130176
#     0.4089641373839995
#     0.947830318888939
#     1e-16
#     1e-16
# max time: 5000.0 / alpha0: 0.4
#     0.8624239895311705
#     0.7823742317280503
#     0.2255185056197585
#     0.7420535416753371
#     0.6510563142076636
#     0.40311443863148805
#     0.3197156922744048
#     0.15942789303325067
#     0.5761294408487171
#     0.26472527041125227
# max time: 5000.0 / alpha0: 0.6
#     0.6717169459098384
#     0.3683734696338623
#     0.2338351079518912
#     0.3781086099666196
#     0.586677968297243
#     0.6560912698739652
#     0.7122842950990468
#     0.5979670014835915
#     1e-16
#     0.5418237491991598
# max time: 5000.0 / alpha0: 0.8
#     0.2396795366719181
#     0.23263737877993132
#     0.23594831190680654
#     0.46980222715908126
#     0.40413861191488204
#     0.4974482689565204
#     0.1752415721252299
#     0.6184913944122044
#     0.556528975854143
#     0.37643873464805605
# max time: 4000.0 / alpha0: 0.2
#     1e-16
#     1.1747786651952177
#     1.2394579963544603
#     1.2138189854827144
#     0.8437254795135066
#     0.8295078055828766
#     1e-16
#     1e-16
#     1.2507006740550028
#     1.1084683856742537
# max time: 4000.0 / alpha0: 0.4
#     0.7676049472008941
#     0.6138587763182137
#     0.8028718837698425
#     0.6940034452177831
#     0.4116508923984014
#     0.4100563269887864
#     1.0125557436318948
#     1e-16
#     0.6458672580173955
#     0.8678378910402227
# max time: 4000.0 / alpha0: 0.6
#     0.464860660453556
#     0.45772549202617857
#     0.3942636191610622
#     0.6639307778716519
#     0.7986774725598622
#     0.7293518810147906
#     0.77747613086792
#     0.5567960775083655
#     1e-16
#     1e-16
# max time: 4000.0 / alpha0: 0.8
#     0.5244325479363745
#     0.7115981502035373
#     0.6710460692360705
#     0.5409251864114117
#     0.45921702594393665
#     0.662633888879641
#     0.588704373537091
#     0.3698426165550092
#     0.29227389321593444
#     0.6174181425318195
# max time: 3500.0 / alpha0: 0.2
#     0.9904524725422088
#     1.2533530239240345
#     1e-16
#     1e-16
#     0.9339580217661352
#     1e-16
#     0.7474577417331365
#     1.0525204779272672
#     1e-16
#     1.0612423023751913
# max time: 3500.0 / alpha0: 0.4
#     0.6487177929115829
#     0.9064893336704293
#     0.7904607556914751
#     1e-16
#     0.6515829754763719
#     0.5805120066645859
#     0.7713038298978667
#     0.9273671458729408
#     0.07824062382824912
#     0.7696031728469215
# max time: 3500.0 / alpha0: 0.6
#     0.7727848638864244
#     1e-16
#     0.6577486084410805
#     0.45765308759855444
#     0.8919104213956061
#     0.4411586353986957
#     0.7153345544585298
#     0.4620455280815535
#     0.7799140588841612
#     1e-16
# max time: 3500.0 / alpha0: 0.8
#     0.07716492792683348
#     0.4569734294984801
#     0.4340528323591612
#     0.4164857363291453
#     0.2692343289550916
#     0.692204649041504
#     0.26116911764415446
#     0.27505320138529477
#     0.16366323179901815
#     0.6534762991798347
# max time: 3000.0 / alpha0: 0.2
#     1e-16
#     1.2725006457628285
#     0.167852279106195
#     0.22644960973817946
#     1e-16
#     1e-16
#     1e-16
#     1.2971152173697573
#     1e-16
#     1e-16
# max time: 3000.0 / alpha0: 0.4
#     0.803866536386445
#     1.1011869058396642
#     0.7387424924482537
#     0.6374718022480463
#     0.0033586684295214865
#     0.09507485042405388
#     0.19292379496286655
#     1.0537839454169544
#     0.6822419491420377
#     0.459215504150593
# max time: 3000.0 / alpha0: 0.6
#     0.5706053152944881
#     1e-16
#     1e-16
#     0.6939207154753616
#     0.6720045946087804
#     0.8403215105907305
#     0.7529138452978166
#     0.010696934164310657
#     0.5711249257916745
#     1e-16
# max time: 3000.0 / alpha0: 0.8
#     0.04398537711208719
#     0.6384263177154667
#     0.7953977516049628
#     0.7068889297486318
#     0.27727824521992267
#     0.6453158401867267
#     0.48454707696078136
#     0.3311200169403265
#     0.23515588054400532
#     0.5707423779430876
# max time: 2500.0 / alpha0: 0.2
#     1e-16
#     1.027347491526554
#     1e-16
#     1e-16
#     1e-16
#     1e-16
#     1.322015307514831
#     0.9793598684389809
#     1.1850526427186177
#     1.2714195917898188
# max time: 2500.0 / alpha0: 0.4
#     0.7811812829510801
#     0.7911804053227214
#     0.34750484386953373
#     0.6318597892587728
#     0.541239159839239
#     0.6877741898364822
#     0.7937887682433151
#     1e-16
#     0.8019765166653778
#     0.719237939199545
# max time: 2500.0 / alpha0: 0.6
#     0.6346540187269792
#     1e-16
#     0.6056292669378889
#     1e-16
#     0.9014359808649713
#     0.547504299545878
#     0.8932970616321403
#     0.7820553123488783
#     0.44644260411823206
#     0.24477284058061607
# max time: 2500.0 / alpha0: 0.8
#     0.10078252523185888
#     0.4962504747901667
#     1e-16
#     0.5683149988604566
#     0.39728777122551406
#     0.7127337155957433
#     0.31109191014013826
#     0.13002249788260986
#     0.7558820042894834
#     0.44868813081161313
# max time: 2000.0 / alpha0: 0.2
#     1e-16
#     1e-16
#     1e-16
#     1e-16
#     0.6203389971082253
#     1e-16
#     1.1493381970612384
#     1e-16
#     1.2350030584180818
#     0.832767693559968
# max time: 2000.0 / alpha0: 0.4
#     0.830972533652298
#     0.830972533652298
#     1e-16
#     1e-16
#     0.8794352124433769
#     1e-16
#     1.034671323959
#     0.703027305362384
#     0.763318185986521
#     0.6862855583751524
# max time: 2000.0 / alpha0: 0.6
#     0.3117738113882574
#     0.3117738113882574
#     0.606614116245958
#     0.378199612112434
#     0.275713128252378
#     0.3917585859182528
#     1e-16
#     0.6328507336945781
#     0.04235368539201892
#     0.384209332945524
# max time: 2000.0 / alpha0: 0.8
#     0.4486150930560596
#     0.4486150930560596
#     0.22416202289208845
#     0.7174631969968269
#     0.4280356049976516
#     0.6735685022952194
#     0.5300283347682624
#     1e-16
#     0.15310367767568042
#     0.26201079443026676
# max time: 1000.0 / alpha0: 0.2
#     0.9910646710074094
#     0.9910646710074094
#     1.2939994231585847
#     1.0409153757534286
#     1.3045053410404384
#     1.1394500549309172
#     1.3542020471031975
#     1e-16
#     1e-16
#     0.0003251294813854646
# max time: 1000.0 / alpha0: 0.4
#     0.8768437359907765
#     0.8768437359907765
#     1.172066725136415
#     1e-16
#     0.9786928557729815
#     1e-16
#     1e-16
#     1.1643205836523283
#     0.7158115596846911
#     1.0640536468396706
# max time: 1000.0 / alpha0: 0.6
#     1e-16
#     1e-16
#     1e-16
#     0.8439117659005777
#     0.2344556330583184
#     0.8957164507475859
#     0.8818073540996234
#     0.5790590075292715
#     1e-16
#     1.04875833305587
# max time: 1000.0 / alpha0: 0.8
#     1e-16
#     1e-16
#     0.9411081997742126
#     0.40100601853874696
#     0.6242284742134452
#     0.19129491727093753
#     1e-16
#     0.3480550559827168
#     0.8616982971615448
#     1e-16
# max time: 100.0 / alpha0: 0.2
#     1.034680916266905
#     1.034680916266905
#     1e-16
#     1e-16
#     1.226149985971281
#     1e-16
#     1e-16
#     0.22672972597696953
#     0.35316757027930434
#     1.028730291921052
# max time: 100.0 / alpha0: 0.4
#     0.9358534648493191
#     0.9358534648493191
#     1.1015476069275714
#     1e-16
#     0.8155720453216437
#     0.7143513866217943
#     1e-16
#     1.1356325858305563
#     0.8061137726812162
#     1.033043475038706
# max time: 100.0 / alpha0: 0.6
#     1.0132369792325595
#     1.0132369792325595
#     0.37330771567449583
#     0.92345224350326
#     0.2804167918838389
#     1e-16
#     0.21729471455683003
#     1e-16
#     1e-16
#     0.5323938700545621
# max time: 100.0 / alpha0: 0.8
#     1e-16
#     1e-16
#     0.5981232525146742
#     0.17254441583296093
#     1.1493237158249057
#     1.0795494468128195
#     0.5740953643246876
#     1e-16
#     1e-16
#     0.7132815642038922

# %%
pkl_results
# Out:
# [{'max_time': 100.0,
#   'alpha': 0.2,
#   'theta': array([5.33e-01, 6.41e-01, 9.82e-02, 1.00e-16, 1.03e+00]),
#   'trial': 0},
#  {'max_time': 100.0,
#   'alpha': 0.4,
#   'theta': array([0.6 , 0.  , 1.  , 1.33, 0.94]),
#   'trial': 0},
#  {'max_time': 100.0,
#   'alpha': 0.6,
#   'theta': array([0.56, 0.25, 1.  , 1.81, 1.01]),
#   'trial': 0},
#  {'max_time': 100.0,
#   'alpha': 0.8,
#   'theta': array([1.54e+00, 7.29e-01, 8.94e-01, 7.45e-01, 1.00e-16]),
#   'trial': 0},
#  {'max_time': 1000.0,
#   'alpha': 0.2,
#   'theta': array([0.43, 0.47, 0.48, 1.79, 0.99]),
#   'trial': 0},
#  {'max_time': 1000.0,
#   'alpha': 0.4,
#   'theta': array([0.54, 0.55, 0.78, 1.29, 0.88]),
#   'trial': 0},
#  {'max_time': 1000.0,
#   'alpha': 0.6,
#   'theta': array([1.48e+00, 1.45e+00, 3.96e-01, 1.31e+00, 1.00e-16]),
#   'trial': 0},
#  {'max_time': 1000.0,
#   'alpha': 0.8,
#   'theta': array([1.46e+00, 1.54e+00, 4.92e-01, 1.47e+00, 1.00e-16]),
#   'trial': 0},
#  {'max_time': 2000.0,
#   'alpha': 0.2,
#   'theta': array([1.45e+00, 1.54e+00, 1.10e-01, 1.49e+00, 1.00e-16]),
#   'trial': 0},
#  {'max_time': 2000.0,
#   'alpha': 0.4,
#   'theta': array([0.62, 0.62, 0.7 , 1.29, 0.83]),
#   'trial': 0},
#  {'max_time': 2000.0,
#   'alpha': 0.6,
#   'theta': array([1.09, 1.19, 0.54, 1.28, 0.31]),
#   'trial': 0},
#  {'max_time': 2000.0,
#   'alpha': 0.8,
#   'theta': array([1.02, 0.95, 0.81, 1.37, 0.45]),
#   'trial': 0},
#  {'max_time': 100.0,
#   'alpha': 0.2,
#   'theta': array([5.33e-01, 6.41e-01, 9.82e-02, 1.00e-16, 1.03e+00]),
#   'trial': 1},
#  {'max_time': 100.0,
#   'alpha': 0.4,
#   'theta': array([0.6 , 0.  , 1.  , 1.33, 0.94]),
#   'trial': 1},
#  {'max_time': 100.0,
#   'alpha': 0.6,
#   'theta': array([0.56, 0.25, 1.  , 1.81, 1.01]),
#   'trial': 1},
#  {'max_time': 100.0,
#   'alpha': 0.8,
#   'theta': array([1.54e+00, 7.29e-01, 8.94e-01, 7.45e-01, 1.00e-16]),
#   'trial': 1},
#  {'max_time': 1000.0,
#   'alpha': 0.2,
#   'theta': array([0.43, 0.47, 0.48, 1.79, 0.99]),
#   'trial': 1},
#  {'max_time': 1000.0,
#   'alpha': 0.4,
#   'theta': array([0.54, 0.55, 0.78, 1.29, 0.88]),
#   'trial': 1},
#  {'max_time': 1000.0,
#   'alpha': 0.6,
#   'theta': array([1.48e+00, 1.45e+00, 3.96e-01, 1.31e+00, 1.00e-16]),
#   'trial': 1},
#  {'max_time': 1000.0,
#   'alpha': 0.8,
#   'theta': array([1.46e+00, 1.54e+00, 4.92e-01, 1.47e+00, 1.00e-16]),
#   'trial': 1},
#  {'max_time': 2000.0,
#   'alpha': 0.2,
#   'theta': array([1.45e+00, 1.54e+00, 1.10e-01, 1.49e+00, 1.00e-16]),
#   'trial': 1},
#  {'max_time': 2000.0,
#   'alpha': 0.4,
#   'theta': array([0.62, 0.62, 0.7 , 1.29, 0.83]),
#   'trial': 1},
#  {'max_time': 2000.0,
#   'alpha': 0.6,
#   'theta': array([1.09, 1.19, 0.54, 1.28, 0.31]),
#   'trial': 1},
#  {'max_time': 2000.0,
#   'alpha': 0.8,
#   'theta': array([1.02, 0.95, 0.81, 1.37, 0.45]),
#   'trial': 1},
#  {'max_time': 2500.0,
#   'alpha': 0.2,
#   'theta': array([1.53e+00, 1.40e+00, 1.86e-01, 1.44e+00, 1.00e-16]),
#   'trial': 0},
#  {'max_time': 2500.0,
#   'alpha': 0.4,
#   'theta': array([0.69, 0.7 , 0.54, 1.42, 0.78]),
#   'trial': 0},
#  {'max_time': 2500.0,
#   'alpha': 0.6,
#   'theta': array([0.92, 0.79, 0.68, 1.31, 0.63]),
#   'trial': 0},
#  {'max_time': 2500.0,
#   'alpha': 0.8,
#   'theta': array([1.35, 1.51, 0.58, 1.16, 0.1 ]),
#   'trial': 0},
#  {'max_time': 2500.0,
#   'alpha': 0.2,
#   'theta': array([0.5 , 0.42, 0.59, 0.99, 1.03]),
#   'trial': 1},
#  {'max_time': 2500.0,
#   'alpha': 0.4,
#   'theta': array([0.7 , 0.63, 0.67, 1.24, 0.79]),
#   'trial': 1},
#  {'max_time': 2500.0,
#   'alpha': 0.6,
#   'theta': array([1.52e+00, 1.62e+00, 3.55e-01, 1.08e+00, 1.00e-16]),
#   'trial': 1},
#  {'max_time': 2500.0,
#   'alpha': 0.8,
#   'theta': array([1.01, 0.89, 0.97, 1.25, 0.5 ]),
#   'trial': 1},
#  {'max_time': 3000.0,
#   'alpha': 0.2,
#   'theta': array([1.50e+00, 1.46e+00, 1.52e-01, 1.57e+00, 1.00e-16]),
#   'trial': 0},
#  {'max_time': 3000.0,
#   'alpha': 0.4,
#   'theta': array([0.63, 0.57, 0.68, 1.02, 0.8 ]),
#   'trial': 0},
#  {'max_time': 3000.0,
#   'alpha': 0.6,
#   'theta': array([0.99, 0.95, 0.58, 1.32, 0.57]),
#   'trial': 0},
#  {'max_time': 3000.0,
#   'alpha': 0.8,
#   'theta': array([1.4 , 1.46, 0.59, 1.15, 0.04]),
#   'trial': 0},
#  {'max_time': 3500.0,
#   'alpha': 0.2,
#   'theta': array([0.53, 0.48, 0.51, 1.1 , 0.99]),
#   'trial': 0},
#  {'max_time': 3500.0,
#   'alpha': 0.4,
#   'theta': array([0.84, 0.85, 0.53, 0.66, 0.65]),
#   'trial': 0},
#  {'max_time': 3500.0,
#   'alpha': 0.6,
#   'theta': array([0.73, 0.65, 0.82, 1.29, 0.77]),
#   'trial': 0},
#  {'max_time': 3500.0,
#   'alpha': 0.8,
#   'theta': array([1.44, 1.48, 0.59, 1.36, 0.08]),
#   'trial': 0},
#  {'max_time': 3000.0,
#   'alpha': 0.2,
#   'theta': array([0.27, 0.16, 1.  , 1.36, 1.27]),
#   'trial': 1},
#  {'max_time': 3000.0,
#   'alpha': 0.4,
#   'theta': array([0.4 , 0.4 , 0.96, 1.34, 1.1 ]),
#   'trial': 1},
#  {'max_time': 3000.0,
#   'alpha': 0.6,
#   'theta': array([1.53e+00, 1.61e+00, 3.66e-01, 1.43e+00, 1.00e-16]),
#   'trial': 1},
#  {'max_time': 3000.0,
#   'alpha': 0.8,
#   'theta': array([0.84, 0.84, 0.99, 1.55, 0.64]),
#   'trial': 1},
#  {'max_time': 3500.0,
#   'alpha': 0.2,
#   'theta': array([0.26, 0.28, 0.68, 1.7 , 1.25]),
#   'trial': 1},
#  {'max_time': 3500.0,
#   'alpha': 0.4,
#   'theta': array([0.56, 0.64, 0.65, 1.65, 0.91]),
#   'trial': 1},
#  {'max_time': 3500.0,
#   'alpha': 0.6,
#   'theta': array([1.50e+00, 1.59e+00, 3.77e-01, 1.55e+00, 1.00e-16]),
#   'trial': 1},
#  {'max_time': 3500.0,
#   'alpha': 0.8,
#   'theta': array([1.03, 1.01, 0.79, 1.34, 0.46]),
#   'trial': 1},
#  {'max_time': 100.0,
#   'alpha': 0.2,
#   'theta': array([1.85e+00, 1.19e+00, 2.75e-01, 7.86e-01, 1.00e-16]),
#   'trial': 2},
#  {'max_time': 100.0,
#   'alpha': 0.4,
#   'theta': array([2.72e-01, 9.10e-01, 1.00e-16, 8.94e-02, 1.10e+00]),
#   'trial': 2},
#  {'max_time': 100.0,
#   'alpha': 0.6,
#   'theta': array([1.25, 0.77, 0.77, 2.3 , 0.37]),
#   'trial': 2},
#  {'max_time': 100.0,
#   'alpha': 0.8,
#   'theta': array([0.91, 0.83, 1.  , 0.84, 0.6 ]),
#   'trial': 2},
#  {'max_time': 1000.0,
#   'alpha': 0.2,
#   'theta': array([0.22, 0.38, 0.37, 5.3 , 1.29]),
#   'trial': 2},
#  {'max_time': 1000.0,
#   'alpha': 0.4,
#   'theta': array([0.33, 0.51, 0.97, 1.87, 1.17]),
#   'trial': 2},
#  {'max_time': 1000.0,
#   'alpha': 0.6,
#   'theta': array([1.50e+00, 1.49e+00, 3.57e-01, 1.66e+00, 1.00e-16]),
#   'trial': 2},
#  {'max_time': 1000.0,
#   'alpha': 0.8,
#   'theta': array([0.53, 0.79, 1.  , 1.89, 0.94]),
#   'trial': 2},
#  {'max_time': 2000.0,
#   'alpha': 0.2,
#   'theta': array([1.62e+00, 1.45e+00, 1.52e-01, 9.74e-01, 1.00e-16]),
#   'trial': 2},
#  {'max_time': 2000.0,
#   'alpha': 0.4,
#   'theta': array([1.49e+00, 1.60e+00, 1.82e-01, 2.24e+00, 1.00e-16]),
#   'trial': 2},
#  {'max_time': 2000.0,
#   'alpha': 0.6,
#   'theta': array([0.91, 1.05, 0.52, 2.19, 0.61]),
#   'trial': 2},
#  {'max_time': 2000.0,
#   'alpha': 0.8,
#   'theta': array([1.24, 1.24, 0.76, 1.31, 0.22]),
#   'trial': 2},
#  {'max_time': 2500.0,
#   'alpha': 0.2,
#   'theta': array([1.44e+00, 1.44e+00, 1.58e-01, 1.47e+00, 1.00e-16]),
#   'trial': 2},
#  {'max_time': 2500.0,
#   'alpha': 0.4,
#   'theta': array([1.15, 1.13, 0.4 , 1.23, 0.35]),
#   'trial': 2},
#  {'max_time': 2500.0,
#   'alpha': 0.6,
#   'theta': array([0.94, 0.96, 0.55, 1.39, 0.61]),
#   'trial': 2},
#  {'max_time': 2500.0,
#   'alpha': 0.8,
#   'theta': array([1.51e+00, 1.53e+00, 5.16e-01, 1.23e+00, 1.00e-16]),
#   'trial': 2},
#  {'max_time': 3000.0,
#   'alpha': 0.2,
#   'theta': array([1.34, 1.37, 0.21, 0.92, 0.17]),
#   'trial': 2},
#  {'max_time': 3000.0,
#   'alpha': 0.4,
#   'theta': array([0.8 , 0.76, 0.53, 1.34, 0.74]),
#   'trial': 2},
#  {'max_time': 3000.0,
#   'alpha': 0.6,
#   'theta': array([1.50e+00, 1.42e+00, 3.92e-01, 1.43e+00, 1.00e-16]),
#   'trial': 2},
#  {'max_time': 3000.0,
#   'alpha': 0.8,
#   'theta': array([0.71, 0.73, 1.  , 1.31, 0.8 ]),
#   'trial': 2},
#  {'max_time': 3500.0,
#   'alpha': 0.2,
#   'theta': array([1.52e+00, 1.52e+00, 1.25e-01, 1.20e+00, 1.00e-16]),
#   'trial': 2},
#  {'max_time': 3500.0,
#   'alpha': 0.4,
#   'theta': array([0.69, 0.71, 0.63, 1.22, 0.79]),
#   'trial': 2},
#  {'max_time': 3500.0,
#   'alpha': 0.6,
#   'theta': array([0.79, 0.94, 0.62, 1.62, 0.66]),
#   'trial': 2},
#  {'max_time': 3500.0,
#   'alpha': 0.8,
#   'theta': array([1.13, 1.15, 0.66, 1.53, 0.43]),
#   'trial': 2},
#  {'max_time': 100.0,
#   'alpha': 0.2,
#   'theta': array([1.63e+00, 1.41e+00, 2.06e-01, 3.66e+00, 1.00e-16]),
#   'trial': 3},
#  {'max_time': 100.0,
#   'alpha': 0.4,
#   'theta': array([1.84e+00, 3.82e-01, 9.05e-01, 4.92e-01, 1.00e-16]),
#   'trial': 3},
#  {'max_time': 100.0,
#   'alpha': 0.6,
#   'theta': array([0.44, 0.62, 1.  , 3.25, 0.92]),
#   'trial': 3},
#  {'max_time': 100.0,
#   'alpha': 0.8,
#   'theta': array([1.47, 1.11, 1.  , 0.84, 0.17]),
#   'trial': 3},
#  {'max_time': 1000.0,
#   'alpha': 0.2,
#   'theta': array([5.28e-01, 6.24e-01, 1.00e-16, 7.36e-02, 1.04e+00]),
#   'trial': 3},
#  {'max_time': 1000.0,
#   'alpha': 0.4,
#   'theta': array([1.52e+00, 1.49e+00, 3.59e-01, 7.20e-01, 1.00e-16]),
#   'trial': 3},
#  {'max_time': 1000.0,
#   'alpha': 0.6,
#   'theta': array([0.67, 0.53, 1.  , 1.48, 0.84]),
#   'trial': 3},
#  {'max_time': 1000.0,
#   'alpha': 0.8,
#   'theta': array([1.1 , 1.16, 0.74, 1.23, 0.4 ]),
#   'trial': 3},
#  {'max_time': 2000.0,
#   'alpha': 0.2,
#   'theta': array([1.47e+00, 1.15e+00, 3.48e-01, 3.84e-02, 1.00e-16]),
#   'trial': 3},
#  {'max_time': 2000.0,
#   'alpha': 0.4,
#   'theta': array([1.54e+00, 1.41e+00, 3.40e-01, 9.94e-01, 1.00e-16]),
#   'trial': 3},
#  {'max_time': 2000.0,
#   'alpha': 0.6,
#   'theta': array([1.08, 1.03, 0.58, 1.13, 0.38]),
#   'trial': 3},
#  {'max_time': 2000.0,
#   'alpha': 0.8,
#   'theta': array([0.81, 0.83, 0.92, 1.17, 0.72]),
#   'trial': 3},
#  {'max_time': 2500.0,
#   'alpha': 0.2,
#   'theta': array([1.47e+00, 1.60e+00, 9.75e-02, 2.36e+00, 1.00e-16]),
#   'trial': 3},
#  {'max_time': 2500.0,
#   'alpha': 0.4,
#   'theta': array([0.92, 0.81, 0.43, 1.08, 0.63]),
#   'trial': 3},
#  {'max_time': 2500.0,
#   'alpha': 0.6,
#   'theta': array([1.51e+00, 1.50e+00, 4.17e-01, 1.13e+00, 1.00e-16]),
#   'trial': 3},
#  {'max_time': 2500.0,
#   'alpha': 0.8,
#   'theta': array([0.97, 0.92, 0.84, 1.44, 0.57]),
#   'trial': 3},
#  {'max_time': 3000.0,
#   'alpha': 0.2,
#   'theta': array([1.34, 1.24, 0.18, 1.21, 0.23]),
#   'trial': 3},
#  {'max_time': 3000.0,
#   'alpha': 0.4,
#   'theta': array([0.87, 0.75, 0.55, 0.76, 0.64]),
#   'trial': 3},
#  {'max_time': 3000.0,
#   'alpha': 0.6,
#   'theta': array([0.78, 0.79, 0.71, 1.47, 0.69]),
#   'trial': 3},
#  {'max_time': 3000.0,
#   'alpha': 0.8,
#   'theta': array([0.79, 0.74, 1.  , 1.42, 0.71]),
#   'trial': 3},
#  {'max_time': 3500.0,
#   'alpha': 0.2,
#   'theta': array([1.52e+00, 1.51e+00, 1.03e-01, 1.55e+00, 1.00e-16]),
#   'trial': 3},
#  {'max_time': 3500.0,
#   'alpha': 0.4,
#   'theta': array([1.48e+00, 1.55e+00, 2.91e-01, 1.32e+00, 1.00e-16]),
#   'trial': 3},
#  {'max_time': 3500.0,
#   'alpha': 0.6,
#   'theta': array([1.06, 1.01, 0.64, 1.04, 0.46]),
#   'trial': 3},
#  {'max_time': 3500.0,
#   'alpha': 0.8,
#   'theta': array([1.13, 0.87, 0.88, 1.06, 0.42]),
#   'trial': 3},
#  {'max_time': 100.0,
#   'alpha': 0.2,
#   'theta': array([0.26, 0.11, 1.  , 1.99, 1.23]),
#   'trial': 4},
#  {'max_time': 100.0,
#   'alpha': 0.4,
#   'theta': array([0.32, 0.57, 1.  , 5.02, 0.82]),
#   'trial': 4},
#  {'max_time': 100.0,
#   'alpha': 0.6,
#   'theta': array([0.98, 0.72, 0.81, 0.77, 0.28]),
#   'trial': 4},
#  {'max_time': 100.0,
#   'alpha': 0.8,
#   'theta': array([0.46, 0.51, 1.  , 1.  , 1.15]),
#   'trial': 4},
#  {'max_time': 1000.0,
#   'alpha': 0.2,
#   'theta': array([0.18, 0.16, 1.  , 1.32, 1.3 ]),
#   'trial': 4},
#  {'max_time': 1000.0,
#   'alpha': 0.4,
#   'theta': array([0.52, 0.38, 1.  , 1.59, 0.98]),
#   'trial': 4},
#  {'max_time': 1000.0,
#   'alpha': 0.6,
#   'theta': array([1.23, 1.06, 0.54, 1.15, 0.23]),
#   'trial': 4},
#  {'max_time': 1000.0,
#   'alpha': 0.8,
#   'theta': array([0.94, 0.85, 1.  , 1.28, 0.62]),
#   'trial': 4},
#  {'max_time': 2000.0,
#   'alpha': 0.2,
#   'theta': array([0.86, 0.81, 0.34, 1.1 , 0.62]),
#   'trial': 4},
#  {'max_time': 2000.0,
#   'alpha': 0.4,
#   'theta': array([0.56, 0.68, 0.65, 1.15, 0.88]),
#   'trial': 4},
#  {'max_time': 2000.0,
#   'alpha': 0.6,
#   'theta': array([1.29, 1.33, 0.47, 1.65, 0.28]),
#   'trial': 4},
#  {'max_time': 2000.0,
#   'alpha': 0.8,
#   'theta': array([1.07, 1.01, 0.76, 1.44, 0.43]),
#   'trial': 4},
#  {'max_time': 2500.0,
#   'alpha': 0.2,
#   'theta': array([1.50e+00, 1.54e+00, 1.18e-01, 1.45e+00, 1.00e-16]),
#   'trial': 4},
#  {'max_time': 2500.0,
#   'alpha': 0.4,
#   'theta': array([0.96, 0.98, 0.42, 1.49, 0.54]),
#   'trial': 4},
#  {'max_time': 2500.0,
#   'alpha': 0.6,
#   'theta': array([0.61, 0.58, 1.  , 1.09, 0.9 ]),
#   'trial': 4},
#  {'max_time': 2500.0,
#   'alpha': 0.8,
#   'theta': array([1.08, 1.21, 0.66, 1.17, 0.4 ]),
#   'trial': 4},
#  {'max_time': 3000.0,
#   'alpha': 0.2,
#   'theta': array([1.44e+00, 1.44e+00, 1.55e-01, 1.42e+00, 1.00e-16]),
#   'trial': 4},
#  {'max_time': 3000.0,
#   'alpha': 0.4,
#   'theta': array([1.47, 1.52, 0.25, 1.21, 0.  ]),
#   'trial': 4},
#  {'max_time': 3000.0,
#   'alpha': 0.6,
#   'theta': array([0.83, 0.78, 0.73, 1.34, 0.67]),
#   'trial': 4},
#  {'max_time': 3000.0,
#   'alpha': 0.8,
#   'theta': array([1.17, 1.02, 0.78, 1.07, 0.28]),
#   'trial': 4},
#  {'max_time': 3500.0,
#   'alpha': 0.2,
#   'theta': array([0.6 , 0.46, 0.41, 1.61, 0.93]),
#   'trial': 4},
#  {'max_time': 3500.0,
#   'alpha': 0.4,
#   'theta': array([0.85, 0.81, 0.52, 1.4 , 0.65]),
#   'trial': 4},
#  {'max_time': 3500.0,
#   'alpha': 0.6,
#   'theta': array([0.63, 0.58, 1.  , 1.36, 0.89]),
#   'trial': 4},
#  {'max_time': 3500.0,
#   'alpha': 0.8,
#   'theta': array([1.25, 1.14, 0.74, 1.17, 0.27]),
#   'trial': 4},
#  {'max_time': 100.0,
#   'alpha': 0.2,
#   'theta': array([1.32e+00, 1.58e+00, 2.84e-01, 1.92e+00, 1.00e-16]),
#   'trial': 5},
#  {'max_time': 100.0,
#   'alpha': 0.4,
#   'theta': array([0.63, 0.65, 1.  , 0.07, 0.71]),
#   'trial': 5},
#  {'max_time': 100.0,
#   'alpha': 0.6,
#   'theta': array([1.91e+00, 3.01e-01, 1.00e+00, 1.40e-01, 1.00e-16]),
#   'trial': 5},
#  {'max_time': 100.0,
#   'alpha': 0.8,
#   'theta': array([2.35e-01, 1.03e+00, 1.95e-01, 1.90e-04, 1.08e+00]),
#   'trial': 5},
#  {'max_time': 1000.0,
#   'alpha': 0.2,
#   'theta': array([0.38, 0.42, 0.42, 2.89, 1.14]),
#   'trial': 5},
#  {'max_time': 1000.0,
#   'alpha': 0.4,
#   'theta': array([1.52e+00, 1.36e+00, 3.25e-01, 1.29e+00, 1.00e-16]),
#   'trial': 5},
#  {'max_time': 1000.0,
#   'alpha': 0.6,
#   'theta': array([0.55, 0.61, 0.94, 1.3 , 0.9 ]),
#   'trial': 5},
#  {'max_time': 1000.0,
#   'alpha': 0.8,
#   'theta': array([1.29, 1.19, 0.74, 1.01, 0.19]),
#   'trial': 5},
#  {'max_time': 2000.0,
#   'alpha': 0.2,
#   'theta': array([1.54e+00, 1.50e+00, 1.36e-01, 1.73e+00, 1.00e-16]),
#   'trial': 5},
#  {'max_time': 2000.0,
#   'alpha': 0.4,
#   'theta': array([1.51e+00, 1.45e+00, 2.72e-01, 1.25e+00, 1.00e-16]),
#   'trial': 5},
#  {'max_time': 2000.0,
#   'alpha': 0.6,
#   'theta': array([1.15, 1.07, 0.55, 1.18, 0.39]),
#   'trial': 5},
#  {'max_time': 2000.0,
#   'alpha': 0.8,
#   'theta': array([0.83, 0.7 , 1.  , 1.44, 0.67]),
#   'trial': 5},
#  {'max_time': 2500.0,
#   'alpha': 0.2,
#   'theta': array([1.51e+00, 1.41e+00, 1.57e-01, 1.41e+00, 1.00e-16]),
#   'trial': 5},
#  {'max_time': 2500.0,
#   'alpha': 0.4,
#   'theta': array([0.81, 0.68, 0.59, 1.13, 0.69]),
#   'trial': 5},
#  {'max_time': 2500.0,
#   'alpha': 0.6,
#   'theta': array([0.96, 0.81, 0.72, 1.24, 0.55]),
#   'trial': 5},
#  {'max_time': 2500.0,
#   'alpha': 0.8,
#   'theta': array([0.81, 0.86, 0.89, 1.48, 0.71]),
#   'trial': 5},
#  {'max_time': 3000.0,
#   'alpha': 0.2,
#   'theta': array([1.56e+00, 1.54e+00, 1.33e-01, 1.07e+00, 1.00e-16]),
#   'trial': 5},
#  {'max_time': 3000.0,
#   'alpha': 0.4,
#   'theta': array([1.37, 1.49, 0.28, 1.24, 0.1 ]),
#   'trial': 5},
#  {'max_time': 3000.0,
#   'alpha': 0.6,
#   'theta': array([0.68, 0.62, 0.88, 1.21, 0.84]),
#   'trial': 5},
#  {'max_time': 3000.0,
#   'alpha': 0.8,
#   'theta': array([0.81, 0.96, 0.91, 1.38, 0.65]),
#   'trial': 5},
#  {'max_time': 3500.0,
#   'alpha': 0.2,
#   'theta': array([1.52e+00, 1.62e+00, 9.05e-02, 2.10e+00, 1.00e-16]),
#   'trial': 5},
#  {'max_time': 3500.0,
#   'alpha': 0.4,
#   'theta': array([0.92, 0.9 , 0.45, 1.11, 0.58]),
#   'trial': 5},
#  {'max_time': 3500.0,
#   'alpha': 0.6,
#   'theta': array([1.05, 1.07, 0.55, 1.29, 0.44]),
#   'trial': 5},
#  {'max_time': 3500.0,
#   'alpha': 0.8,
#   'theta': array([0.79, 0.8 , 0.97, 1.39, 0.69]),
#   'trial': 5},
#  {'max_time': 100.0,
#   'alpha': 0.2,
#   'theta': array([1.46e+00, 7.63e-01, 4.00e-01, 1.03e+00, 1.00e-16]),
#   'trial': 6},
#  {'max_time': 100.0,
#   'alpha': 0.4,
#   'theta': array([1.56e+00, 1.35e+00, 2.93e-01, 8.30e-01, 1.00e-16]),
#   'trial': 6},
#  {'max_time': 100.0,
#   'alpha': 0.6,
#   'theta': array([1.28, 0.8 , 0.94, 0.56, 0.22]),
#   'trial': 6},
#  {'max_time': 100.0,
#   'alpha': 0.8,
#   'theta': array([0.99, 0.47, 1.  , 1.08, 0.57]),
#   'trial': 6},
#  {'max_time': 1000.0,
#   'alpha': 0.2,
#   'theta': array([0.2 , 0.16, 1.  , 0.34, 1.35]),
#   'trial': 6},
#  {'max_time': 1000.0,
#   'alpha': 0.4,
#   'theta': array([1.46e+00, 1.52e+00, 3.38e-01, 1.31e+00, 1.00e-16]),
#   'trial': 6},
#  {'max_time': 1000.0,
#   'alpha': 0.6,
#   'theta': array([0.55, 0.49, 1.  , 1.54, 0.88]),
#   'trial': 6},
#  {'max_time': 1000.0,
#   'alpha': 0.8,
#   'theta': array([1.48e+00, 1.48e+00, 5.59e-01, 1.36e+00, 1.00e-16]),
#   'trial': 6},
#  {'max_time': 2000.0,
#   'alpha': 0.2,
#   'theta': array([0.34, 0.37, 0.53, 2.3 , 1.15]),
#   'trial': 6},
#  {'max_time': 2000.0,
#   'alpha': 0.4,
#   'theta': array([0.45, 0.4 , 1.  , 1.17, 1.03]),
#   'trial': 6},
#  {'max_time': 2000.0,
#   'alpha': 0.6,
#   'theta': array([1.48e+00, 1.54e+00, 3.70e-01, 1.34e+00, 1.00e-16]),
#   'trial': 6},
#  {'max_time': 2000.0,
#   'alpha': 0.8,
#   'theta': array([0.98, 0.96, 0.86, 1.37, 0.53]),
#   'trial': 6},
#  {'max_time': 2500.0,
#   'alpha': 0.2,
#   'theta': array([0.23, 0.06, 1.  , 1.82, 1.32]),
#   'trial': 6},
#  {'max_time': 2500.0,
#   'alpha': 0.4,
#   'theta': array([0.68, 0.58, 0.76, 0.82, 0.79]),
#   'trial': 6},
#  {'max_time': 2500.0,
#   'alpha': 0.6,
#   'theta': array([0.64, 0.56, 1.  , 1.21, 0.89]),
#   'trial': 6},
#  {'max_time': 2500.0,
#   'alpha': 0.8,
#   'theta': array([1.2 , 1.21, 0.66, 1.25, 0.31]),
#   'trial': 6},
#  {'max_time': 3000.0,
#   'alpha': 0.2,
#   'theta': array([1.40e+00, 1.50e+00, 1.39e-01, 9.62e-01, 1.00e-16]),
#   'trial': 6},
#  {'max_time': 3000.0,
#   'alpha': 0.4,
#   'theta': array([1.37, 1.35, 0.26, 2.07, 0.19]),
#   'trial': 6},
#  {'max_time': 3000.0,
#   'alpha': 0.6,
#   'theta': array([0.74, 0.7 , 0.85, 1.34, 0.75]),
#   'trial': 6},
#  {'max_time': 3000.0,
#   'alpha': 0.8,
#   'theta': array([0.99, 1.15, 0.67, 1.51, 0.48]),
#   'trial': 6},
#  {'max_time': 3500.0,
#   'alpha': 0.2,
#   'theta': array([0.8 , 0.66, 0.31, 1.24, 0.75]),
#   'trial': 6},
#  {'max_time': 3500.0,
#   'alpha': 0.4,
#   'theta': array([0.74, 0.82, 0.43, 1.26, 0.77]),
#   'trial': 6},
#  {'max_time': 3500.0,
#   'alpha': 0.6,
#   'theta': array([0.82, 0.7 , 0.8 , 1.26, 0.72]),
#   'trial': 6},
#  {'max_time': 3500.0,
#   'alpha': 0.8,
#   'theta': array([1.23, 1.2 , 0.66, 1.32, 0.26]),
#   'trial': 6},
#  {'max_time': 100.0,
#   'alpha': 0.2,
#   'theta': array([1.19, 0.23, 1.  , 0.23, 0.23]),
#   'trial': 7},
#  {'max_time': 100.0,
#   'alpha': 0.4,
#   'theta': array([0.28, 0.6 , 1.  , 0.06, 1.14]),
#   'trial': 7},
#  {'max_time': 100.0,
#   'alpha': 0.6,
#   'theta': array([1.28e+00, 8.51e-01, 1.00e+00, 1.29e-01, 1.00e-16]),
#   'trial': 7},
#  {'max_time': 100.0,
#   'alpha': 0.8,
#   'theta': array([1.43e+00, 1.83e+00, 1.62e-01, 5.20e+00, 1.00e-16]),
#   'trial': 7},
#  {'max_time': 1000.0,
#   'alpha': 0.2,
#   'theta': array([1.57e+00, 1.44e+00, 1.41e-01, 2.17e+00, 1.00e-16]),
#   'trial': 7},
#  {'max_time': 1000.0,
#   'alpha': 0.4,
#   'theta': array([0.4 , 0.29, 1.  , 2.1 , 1.16]),
#   'trial': 7},
#  {'max_time': 1000.0,
#   'alpha': 0.6,
#   'theta': array([0.93, 0.75, 0.7 , 1.57, 0.58]),
#   'trial': 7},
#  {'max_time': 1000.0,
#   'alpha': 0.8,
#   'theta': array([1.2 , 1.21, 0.62, 1.27, 0.35]),
#   'trial': 7},
#  {'max_time': 2000.0,
#   'alpha': 0.2,
#   'theta': array([1.47e+00, 1.53e+00, 1.34e-01, 1.56e+00, 1.00e-16]),
#   'trial': 7},
#  {'max_time': 2000.0,
#   'alpha': 0.4,
#   'theta': array([0.78, 0.69, 0.63, 0.72, 0.7 ]),
#   'trial': 7},
#  {'max_time': 2000.0,
#   'alpha': 0.6,
#   'theta': array([0.86, 0.86, 0.68, 1.23, 0.63]),
#   'trial': 7},
#  {'max_time': 2000.0,
#   'alpha': 0.8,
#   'theta': array([1.50e+00, 1.56e+00, 4.81e-01, 1.68e+00, 1.00e-16]),
#   'trial': 7},
#  {'max_time': 2500.0,
#   'alpha': 0.2,
#   'theta': array([0.53, 0.57, 0.34, 1.62, 0.98]),
#   'trial': 7},
#  {'max_time': 2500.0,
#   'alpha': 0.4,
#   'theta': array([1.54e+00, 1.57e+00, 2.37e-01, 1.13e+00, 1.00e-16]),
#   'trial': 7},
#  {'max_time': 2500.0,
#   'alpha': 0.6,
#   'theta': array([0.7 , 0.76, 0.72, 1.25, 0.78]),
#   'trial': 7},
#  {'max_time': 2500.0,
#   'alpha': 0.8,
#   'theta': array([1.37, 1.36, 0.59, 1.1 , 0.13]),
#   'trial': 7},
#  {'max_time': 3000.0,
#   'alpha': 0.2,
#   'theta': array([0.25, 0.2 , 0.73, 1.92, 1.3 ]),
#   'trial': 7},
#  {'max_time': 3000.0,
#   'alpha': 0.4,
#   'theta': array([0.48, 0.48, 0.97, 0.93, 1.05]),
#   'trial': 7},
#  {'max_time': 3000.0,
#   'alpha': 0.6,
#   'theta': array([1.51, 1.42, 0.43, 1.13, 0.01]),
#   'trial': 7},
#  {'max_time': 3000.0,
#   'alpha': 0.8,
#   'theta': array([1.17, 1.19, 0.68, 1.21, 0.33]),
#   'trial': 7},
#  {'max_time': 3500.0,
#   'alpha': 0.2,
#   'theta': array([0.47, 0.44, 0.47, 1.46, 1.05]),
#   'trial': 7},
#  {'max_time': 3500.0,
#   'alpha': 0.4,
#   'theta': array([0.6 , 0.6 , 0.65, 1.12, 0.93]),
#   'trial': 7},
#  {'max_time': 3500.0,
#   'alpha': 0.6,
#   'theta': array([1.03, 1.03, 0.58, 1.32, 0.46]),
#   'trial': 7},
#  {'max_time': 3500.0,
#   'alpha': 0.8,
#   'theta': array([1.21, 1.39, 0.58, 1.56, 0.28]),
#   'trial': 7},
#  {'max_time': 100.0,
#   'alpha': 0.2,
#   'theta': array([1.22, 0.1 , 1.  , 0.71, 0.35]),
#   'trial': 8},
#  {'max_time': 100.0,
#   'alpha': 0.4,
#   'theta': array([0.5 , 0.73, 1.  , 1.07, 0.81]),
#   'trial': 8},
#  {'max_time': 100.0,
#   'alpha': 0.6,
#   'theta': array([1.45e+00, 5.91e-01, 1.00e+00, 3.35e-01, 1.00e-16]),
#   'trial': 8},
#  {'max_time': 100.0,
#   'alpha': 0.8,
#   'theta': array([1.55e+00, 9.42e-01, 8.04e-01, 1.59e-01, 1.00e-16]),
#   'trial': 8},
#  {'max_time': 1000.0,
#   'alpha': 0.2,
#   'theta': array([1.46e+00, 1.67e+00, 6.67e-02, 1.80e+00, 1.00e-16]),
#   'trial': 8},
#  {'max_time': 1000.0,
#   'alpha': 0.4,
#   'theta': array([0.88, 0.83, 0.48, 1.26, 0.72]),
#   'trial': 8},
#  {'max_time': 1000.0,
#   'alpha': 0.6,
#   'theta': array([1.52e+00, 1.61e+00, 3.30e-01, 1.01e+00, 1.00e-16]),
#   'trial': 8},
#  {'max_time': 1000.0,
#   'alpha': 0.8,
#   'theta': array([0.56, 0.85, 1.  , 2.06, 0.86]),
#   'trial': 8},
#  {'max_time': 2000.0,
#   'alpha': 0.2,
#   'theta': array([0.31, 0.07, 1.  , 0.61, 1.24]),
#   'trial': 8},
#  {'max_time': 2000.0,
#   'alpha': 0.4,
#   'theta': array([0.73, 0.7 , 0.58, 1.63, 0.76]),
#   'trial': 8},
#  {'max_time': 2000.0,
#   'alpha': 0.6,
#   'theta': array([1.51, 1.51, 0.38, 1.59, 0.04]),
#   'trial': 8},
#  {'max_time': 2000.0,
#   'alpha': 0.8,
#   'theta': array([1.33, 1.53, 0.5 , 1.71, 0.15]),
#   'trial': 8},
#  {'max_time': 2500.0,
#   'alpha': 0.2,
#   'theta': array([0.36, 0.27, 0.65, 1.21, 1.19]),
#   'trial': 8},
#  {'max_time': 2500.0,
#   'alpha': 0.4,
#   'theta': array([0.71, 0.67, 0.63, 1.51, 0.8 ]),
#   'trial': 8},
#  {'max_time': 2500.0,
#   'alpha': 0.6,
#   'theta': array([1.07, 1.  , 0.6 , 1.56, 0.45]),
#   'trial': 8},
#  {'max_time': 2500.0,
#   'alpha': 0.8,
#   'theta': array([0.73, 0.74, 1.  , 1.25, 0.76]),
#   'trial': 8},
#  {'max_time': 3000.0,
#   'alpha': 0.2,
#   'theta': array([1.50e+00, 1.59e+00, 9.02e-02, 2.39e+00, 1.00e-16]),
#   'trial': 8},
#  {'max_time': 3000.0,
#   'alpha': 0.4,
#   'theta': array([0.78, 0.85, 0.42, 1.47, 0.68]),
#   'trial': 8},
#  {'max_time': 3000.0,
#   'alpha': 0.6,
#   'theta': array([0.93, 0.76, 0.76, 1.19, 0.57]),
#   'trial': 8},
#  {'max_time': 3000.0,
#   'alpha': 0.8,
#   'theta': array([1.26, 1.38, 0.61, 1.25, 0.24]),
#   'trial': 8},
#  {'max_time': 3500.0,
#   'alpha': 0.2,
#   'theta': array([1.44e+00, 1.48e+00, 1.08e-01, 1.51e+00, 1.00e-16]),
#   'trial': 8},
#  {'max_time': 3500.0,
#   'alpha': 0.4,
#   'theta': array([1.42, 1.36, 0.28, 1.35, 0.08]),
#   'trial': 8},
#  {'max_time': 3500.0,
#   'alpha': 0.6,
#   'theta': array([0.73, 0.63, 0.92, 1.11, 0.78]),
#   'trial': 8},
#  {'max_time': 3500.0,
#   'alpha': 0.8,
#   'theta': array([1.36, 1.24, 0.65, 1.05, 0.16]),
#   'trial': 8},
#  {'max_time': 100.0,
#   'alpha': 0.2,
#   'theta': array([6.41e-01, 5.03e-01, 1.00e-16, 1.40e-01, 1.03e+00]),
#   'trial': 9},
#  {'max_time': 100.0,
#   'alpha': 0.4,
#   'theta': array([3.40e-01, 7.83e-01, 1.00e-16, 6.52e-02, 1.03e+00]),
#   'trial': 9},
#  {'max_time': 100.0,
#   'alpha': 0.6,
#   'theta': array([1.  , 0.67, 1.  , 0.49, 0.53]),
#   'trial': 9},
#  {'max_time': 100.0,
#   'alpha': 0.8,
#   'theta': array([0.78, 0.43, 1.  , 2.14, 0.71]),
#   'trial': 9},
#  {'max_time': 1000.0,
#   'alpha': 0.2,
#   'theta': array([1.56e+00, 1.49e+00, 1.61e-01, 1.54e+00, 3.25e-04]),
#   'trial': 9},
#  {'max_time': 1000.0,
#   'alpha': 0.4,
#   'theta': array([0.43, 0.59, 0.69, 1.29, 1.06]),
#   'trial': 9},
#  {'max_time': 1000.0,
#   'alpha': 0.6,
#   'theta': array([0.58, 0.42, 1.  , 1.85, 1.05]),
#   'trial': 9},
#  {'max_time': 1000.0,
#   'alpha': 0.8,
#   'theta': array([1.50e+00, 1.39e+00, 6.69e-01, 9.16e-01, 1.00e-16]),
#   'trial': 9},
#  {'max_time': 2000.0,
#   'alpha': 0.2,
#   'theta': array([0.6 , 0.67, 0.3 , 0.88, 0.83]),
#   'trial': 9},
#  {'max_time': 2000.0,
#   'alpha': 0.4,
#   'theta': array([0.78, 0.78, 0.58, 1.27, 0.69]),
#   'trial': 9},
#  {'max_time': 2000.0,
#   'alpha': 0.6,
#   'theta': array([1.13, 1.16, 0.56, 1.32, 0.38]),
#   'trial': 9},
#  {'max_time': 2000.0,
#   'alpha': 0.8,
#   'theta': array([1.29, 1.12, 0.75, 1.08, 0.26]),
#   'trial': 9},
#  {'max_time': 2500.0,
#   'alpha': 0.2,
#   'theta': array([0.25, 0.15, 1.  , 0.72, 1.27]),
#   'trial': 9},
#  {'max_time': 2500.0,
#   'alpha': 0.4,
#   'theta': array([0.73, 0.82, 0.5 , 1.29, 0.72]),
#   'trial': 9},
#  {'max_time': 2500.0,
#   'alpha': 0.6,
#   'theta': array([1.22, 1.04, 0.65, 0.97, 0.24]),
#   'trial': 9},
#  {'max_time': 2500.0,
#   'alpha': 0.8,
#   'theta': array([1.07, 1.05, 0.73, 1.39, 0.45]),
#   'trial': 9},
#  {'max_time': 3000.0,
#   'alpha': 0.2,
#   'theta': array([1.53e+00, 1.58e+00, 7.83e-02, 2.18e+00, 1.00e-16]),
#   'trial': 9},
#  {'max_time': 3000.0,
#   'alpha': 0.4,
#   'theta': array([1.05, 0.89, 0.49, 1.13, 0.46]),
#   'trial': 9},
#  {'max_time': 3000.0,
#   'alpha': 0.6,
#   'theta': array([1.49e+00, 1.48e+00, 4.41e-01, 1.37e+00, 1.00e-16]),
#   'trial': 9},
#  {'max_time': 3000.0,
#   'alpha': 0.8,
#   'theta': array([0.89, 0.98, 0.89, 1.37, 0.57]),
#   'trial': 9},
#  {'max_time': 3500.0,
#   'alpha': 0.2,
#   'theta': array([0.48, 0.32, 0.58, 0.74, 1.06]),
#   'trial': 9},
#  {'max_time': 3500.0,
#   'alpha': 0.4,
#   'theta': array([0.69, 0.72, 0.56, 1.26, 0.77]),
#   'trial': 9},
#  {'max_time': 3500.0,
#   'alpha': 0.6,
#   'theta': array([1.49e+00, 1.41e+00, 4.94e-01, 1.06e+00, 1.00e-16]),
#   'trial': 9},
#  {'max_time': 3500.0,
#   'alpha': 0.8,
#   'theta': array([0.8 , 0.92, 0.88, 1.45, 0.65]),
#   'trial': 9},
#  {'max_time': 4000.0,
#   'alpha': 0.2,
#   'theta': array([1.52e+00, 1.44e+00, 1.50e-01, 2.13e+00, 1.00e-16]),
#   'trial': 0},
#  {'max_time': 4000.0,
#   'alpha': 0.4,
#   'theta': array([0.72, 0.72, 0.51, 1.42, 0.77]),
#   'trial': 0},
#  {'max_time': 4000.0,
#   'alpha': 0.6,
#   'theta': array([1.07, 1.01, 0.57, 1.35, 0.46]),
#   'trial': 0},
#  {'max_time': 4000.0,
#   'alpha': 0.8,
#   'theta': array([0.95, 1.1 , 0.79, 1.26, 0.52]),
#   'trial': 0},
#  {'max_time': 5000.0,
#   'alpha': 0.2,
#   'theta': array([0.19, 0.22, 0.77, 1.85, 1.32]),
#   'trial': 0},
#  {'max_time': 5000.0,
#   'alpha': 0.4,
#   'theta': array([0.65, 0.59, 0.68, 0.78, 0.86]),
#   'trial': 0},
#  {'max_time': 5000.0,
#   'alpha': 0.6,
#   'theta': array([0.84, 0.8 , 0.67, 1.3 , 0.67]),
#   'trial': 0},
#  {'max_time': 5000.0,
#   'alpha': 0.8,
#   'theta': array([1.24, 1.25, 0.7 , 1.23, 0.24]),
#   'trial': 0},
#  {'max_time': 4000.0,
#   'alpha': 0.2,
#   'theta': array([0.34, 0.35, 0.48, 2.23, 1.17]),
#   'trial': 1},
#  {'max_time': 4000.0,
#   'alpha': 0.4,
#   'theta': array([0.87, 0.9 , 0.47, 1.26, 0.61]),
#   'trial': 1},
#  {'max_time': 4000.0,
#   'alpha': 0.6,
#   'theta': array([1.05, 1.07, 0.59, 1.28, 0.46]),
#   'trial': 1},
#  {'max_time': 4000.0,
#   'alpha': 0.8,
#   'theta': array([0.83, 0.74, 1.  , 1.42, 0.71]),
#   'trial': 1},
#  {'max_time': 5000.0,
#   'alpha': 0.2,
#   'theta': array([1.51e+00, 1.53e+00, 1.13e-01, 1.66e+00, 1.00e-16]),
#   'trial': 1},
#  {'max_time': 5000.0,
#   'alpha': 0.4,
#   'theta': array([0.72, 0.79, 0.5 , 1.43, 0.78]),
#   'trial': 1},
#  {'max_time': 5000.0,
#   'alpha': 0.6,
#   'theta': array([1.14, 1.16, 0.52, 1.7 , 0.37]),
#   'trial': 1},
#  {'max_time': 5000.0,
#   'alpha': 0.8,
#   'theta': array([1.28, 1.3 , 0.64, 1.23, 0.23]),
#   'trial': 1},
#  {'max_time': 4000.0,
#   'alpha': 0.2,
#   'theta': array([0.25, 0.25, 0.87, 1.65, 1.24]),
#   'trial': 2},
#  {'max_time': 4000.0,
#   'alpha': 0.4,
#   'theta': array([0.69, 0.66, 0.65, 1.01, 0.8 ]),
#   'trial': 2},
#  {'max_time': 4000.0,
#   'alpha': 0.6,
#   'theta': array([1.13, 1.07, 0.57, 1.3 , 0.39]),
#   'trial': 2},
#  {'max_time': 4000.0,
#   'alpha': 0.8,
#   'theta': array([0.82, 0.81, 1.  , 1.22, 0.67]),
#   'trial': 2},
#  {'max_time': 5000.0,
#   'alpha': 0.2,
#   'theta': array([1.51e+00, 1.52e+00, 1.17e-01, 1.40e+00, 1.00e-16]),
#   'trial': 2},
#  {'max_time': 5000.0,
#   'alpha': 0.4,
#   'theta': array([1.25, 1.3 , 0.3 , 1.29, 0.23]),
#   'trial': 2},
#  {'max_time': 5000.0,
#   'alpha': 0.6,
#   'theta': array([1.25, 1.15, 0.53, 0.94, 0.23]),
#   'trial': 2},
#  {'max_time': 5000.0,
#   'alpha': 0.8,
#   'theta': array([1.25, 1.31, 0.63, 1.09, 0.24]),
#   'trial': 2},
#  {'max_time': 4000.0,
#   'alpha': 0.2,
#   'theta': array([0.26, 0.26, 0.82, 0.61, 1.21]),
#   'trial': 3},
#  {'max_time': 4000.0,
#   'alpha': 0.4,
#   'theta': array([0.83, 0.65, 0.63, 0.99, 0.69]),
#   'trial': 3},
#  {'max_time': 4000.0,
#   'alpha': 0.6,
#   'theta': array([0.83, 0.77, 0.75, 1.36, 0.66]),
#   'trial': 3},
#  {'max_time': 4000.0,
#   'alpha': 0.8,
#   'theta': array([0.95, 1.04, 0.74, 1.45, 0.54]),
#   'trial': 3},
#  {'max_time': 5000.0,
#   'alpha': 0.2,
#   'theta': array([0.22, 0.25, 0.78, 1.42, 1.27]),
#   'trial': 3},
#  {'max_time': 5000.0,
#   'alpha': 0.4,
#   'theta': array([0.76, 0.8 , 0.48, 1.65, 0.74]),
#   'trial': 3},
#  {'max_time': 5000.0,
#   'alpha': 0.6,
#   'theta': array([1.12, 1.1 , 0.56, 1.26, 0.38]),
#   'trial': 3},
#  {'max_time': 5000.0,
#   'alpha': 0.8,
#   'theta': array([1.06, 1.  , 0.77, 1.22, 0.47]),
#   'trial': 3},
#  {'max_time': 4000.0,
#   'alpha': 0.2,
#   'theta': array([0.67, 0.56, 0.4 , 1.07, 0.84]),
#   'trial': 4},
#  {'max_time': 4000.0,
#   'alpha': 0.4,
#   'theta': array([1.09, 1.06, 0.38, 1.76, 0.41]),
#   'trial': 4},
#  {'max_time': 4000.0,
#   'alpha': 0.6,
#   'theta': array([0.68, 0.6 , 0.9 , 1.38, 0.8 ]),
#   'trial': 4},
#  {'max_time': 4000.0,
#   'alpha': 0.8,
#   'theta': array([1.04, 1.  , 0.84, 1.36, 0.46]),
#   'trial': 4},
#  {'max_time': 5000.0,
#   'alpha': 0.2,
#   'theta': array([0.77, 0.78, 0.27, 1.18, 0.73]),
#   'trial': 4},
#  {'max_time': 5000.0,
#   'alpha': 0.4,
#   'theta': array([0.87, 0.78, 0.54, 1.28, 0.65]),
#   'trial': 4},
#  {'max_time': 5000.0,
#   'alpha': 0.6,
#   'theta': array([0.93, 0.91, 0.63, 1.43, 0.59]),
#   'trial': 4},
#  {'max_time': 5000.0,
#   'alpha': 0.8,
#   'theta': array([1.14, 1.11, 0.75, 1.29, 0.4 ]),
#   'trial': 4},
#  {'max_time': 4000.0,
#   'alpha': 0.2,
#   'theta': array([0.7 , 0.6 , 0.35, 1.97, 0.83]),
#   'trial': 5},
#  {'max_time': 4000.0,
#   'alpha': 0.4,
#   'theta': array([1.09, 1.08, 0.38, 1.5 , 0.41]),
#   'trial': 5},
#  {'max_time': 4000.0,
#   'alpha': 0.6,
#   'theta': array([0.8 , 0.72, 0.83, 1.19, 0.73]),
#   'trial': 5},
#  {'max_time': 4000.0,
#   'alpha': 0.8,
#   'theta': array([0.84, 0.94, 0.85, 1.5 , 0.66]),
#   'trial': 5},
#  {'max_time': 5000.0,
#   'alpha': 0.2,
#   'theta': array([0.81, 0.83, 0.21, 2.03, 0.69]),
#   'trial': 5},
#  {'max_time': 5000.0,
#   'alpha': 0.4,
#   'theta': array([1.1 , 1.13, 0.34, 1.39, 0.4 ]),
#   'trial': 5},
#  {'max_time': 5000.0,
#   'alpha': 0.6,
#   'theta': array([0.83, 0.77, 0.77, 1.1 , 0.66]),
#   'trial': 5},
#  {'max_time': 5000.0,
#   'alpha': 0.8,
#   'theta': array([1.01, 0.97, 0.82, 1.15, 0.5 ]),
#   'trial': 5},
#  {'max_time': 4000.0,
#   'alpha': 0.2,
#   'theta': array([1.56e+00, 1.47e+00, 1.46e-01, 1.21e+00, 1.00e-16]),
#   'trial': 6},
#  {'max_time': 4000.0,
#   'alpha': 0.4,
#   'theta': array([0.49, 0.53, 0.62, 1.58, 1.01]),
#   'trial': 6},
#  {'max_time': 4000.0,
#   'alpha': 0.6,
#   'theta': array([0.7 , 0.65, 0.92, 1.13, 0.78]),
#   'trial': 6},
#  {'max_time': 4000.0,
#   'alpha': 0.8,
#   'theta': array([0.91, 0.8 , 0.96, 1.18, 0.59]),
#   'trial': 6},
#  {'max_time': 5000.0,
#   'alpha': 0.2,
#   'theta': array([1.08, 1.01, 0.26, 1.09, 0.41]),
#   'trial': 6},
#  {'max_time': 5000.0,
#   'alpha': 0.4,
#   'theta': array([1.17, 1.18, 0.33, 1.28, 0.32]),
#   'trial': 6},
#  {'max_time': 5000.0,
#   'alpha': 0.6,
#   'theta': array([0.83, 0.81, 0.67, 1.4 , 0.71]),
#   'trial': 6},
#  {'max_time': 5000.0,
#   'alpha': 0.8,
#   'theta': array([1.28, 1.33, 0.61, 1.16, 0.18]),
#   'trial': 6},
#  {'max_time': 4000.0,
#   'alpha': 0.2,
#   'theta': array([1.53e+00, 1.33e+00, 2.19e-01, 8.67e-01, 1.00e-16]),
#   'trial': 7},
#  {'max_time': 4000.0,
#   'alpha': 0.4,
#   'theta': array([1.56e+00, 1.50e+00, 2.61e-01, 1.38e+00, 1.00e-16]),
#   'trial': 7},
#  {'max_time': 4000.0,
#   'alpha': 0.6,
#   'theta': array([0.96, 0.92, 0.69, 1.29, 0.56]),
#   'trial': 7},
#  {'max_time': 4000.0,
#   'alpha': 0.8,
#   'theta': array([1.1 , 1.12, 0.72, 1.35, 0.37]),
#   'trial': 7},
#  {'max_time': 5000.0,
#   'alpha': 0.2,
#   'theta': array([0.55, 0.54, 0.36, 1.49, 0.95]),
#   'trial': 7},
#  {'max_time': 5000.0,
#   'alpha': 0.4,
#   'theta': array([1.36, 1.44, 0.26, 1.85, 0.16]),
#   'trial': 7},
#  {'max_time': 5000.0,
#   'alpha': 0.6,
#   'theta': array([0.92, 0.89, 0.66, 1.47, 0.6 ]),
#   'trial': 7},
#  {'max_time': 5000.0,
#   'alpha': 0.8,
#   'theta': array([0.9 , 0.99, 0.81, 1.55, 0.62]),
#   'trial': 7},
#  {'max_time': 4000.0,
#   'alpha': 0.2,
#   'theta': array([0.21, 0.22, 0.97, 1.15, 1.25]),
#   'trial': 8},
#  {'max_time': 4000.0,
#   'alpha': 0.4,
#   'theta': array([0.87, 0.7 , 0.63, 0.92, 0.65]),
#   'trial': 8},
#  {'max_time': 4000.0,
#   'alpha': 0.6,
#   'theta': array([1.49e+00, 1.57e+00, 3.58e-01, 1.53e+00, 1.00e-16]),
#   'trial': 8},
#  {'max_time': 4000.0,
#   'alpha': 0.8,
#   'theta': array([1.2 , 1.22, 0.67, 1.23, 0.29]),
#   'trial': 8},
#  {'max_time': 5000.0,
#   'alpha': 0.2,
#   'theta': array([1.52e+00, 1.61e+00, 1.32e-01, 1.17e+00, 1.00e-16]),
#   'trial': 8},
#  {'max_time': 5000.0,
#   'alpha': 0.4,
#   'theta': array([0.89, 0.9 , 0.47, 1.09, 0.58]),
#   'trial': 8},
#  {'max_time': 5000.0,
#   'alpha': 0.6,
#   'theta': array([1.48e+00, 1.58e+00, 3.69e-01, 1.22e+00, 1.00e-16]),
#   'trial': 8},
#  {'max_time': 5000.0,
#   'alpha': 0.8,
#   'theta': array([0.93, 1.02, 0.82, 1.47, 0.56]),
#   'trial': 8},
#  {'max_time': 4000.0,
#   'alpha': 0.2,
#   'theta': array([0.43, 0.36, 0.5 , 1.84, 1.11]),
#   'trial': 9},
#  {'max_time': 4000.0,
#   'alpha': 0.4,
#   'theta': array([0.64, 0.74, 0.45, 1.73, 0.87]),
#   'trial': 9},
#  {'max_time': 4000.0,
#   'alpha': 0.6,
#   'theta': array([1.53e+00, 1.50e+00, 3.90e-01, 1.31e+00, 1.00e-16]),
#   'trial': 9},
#  {'max_time': 4000.0,
#   'alpha': 0.8,
#   'theta': array([0.92, 0.93, 0.83, 1.4 , 0.62]),
#   'trial': 9},
#  {'max_time': 5000.0,
#   'alpha': 0.2,
#   'theta': array([1.48e+00, 1.48e+00, 1.46e-01, 1.95e+00, 1.00e-16]),
#   'trial': 9},
#  {'max_time': 5000.0,
#   'alpha': 0.4,
#   'theta': array([1.23, 1.22, 0.31, 1.2 , 0.26]),
#   'trial': 9},
#  {'max_time': 5000.0,
#   'alpha': 0.6,
#   'theta': array([0.97, 0.93, 0.64, 1.18, 0.54]),
#   'trial': 9},
#  {'max_time': 5000.0,
#   'alpha': 0.8,
#   'theta': array([1.14, 1.11, 0.73, 1.23, 0.38]),
#   'trial': 9},
#  {'max_time': 10000.0,
#   'alpha': 0.2,
#   'theta': array([1.50e+00, 1.46e+00, 1.44e-01, 1.13e+00, 1.00e-16]),
#   'trial': 0},
#  {'max_time': 10000.0,
#   'alpha': 0.4,
#   'theta': array([0.84, 0.83, 0.43, 1.44, 0.67]),
#   'trial': 0},
#  {'max_time': 10000.0,
#   'alpha': 0.6,
#   'theta': array([0.94, 0.96, 0.63, 1.34, 0.56]),
#   'trial': 0},
#  {'max_time': 10000.0,
#   'alpha': 0.8,
#   'theta': array([1.11, 1.08, 0.72, 1.29, 0.41]),
#   'trial': 0},
#  {'max_time': 10000.0,
#   'alpha': 0.2,
#   'theta': array([0.38, 0.38, 0.53, 1.62, 1.13]),
#   'trial': 1},
#  {'max_time': 10000.0,
#   'alpha': 0.4,
#   'theta': array([0.71, 0.73, 0.53, 1.33, 0.79]),
#   'trial': 1},
#  {'max_time': 10000.0,
#   'alpha': 0.6,
#   'theta': array([0.89, 0.85, 0.69, 1.31, 0.65]),
#   'trial': 1},
#  {'max_time': 10000.0,
#   'alpha': 0.8,
#   'theta': array([0.98, 0.93, 0.88, 1.33, 0.54]),
#   'trial': 1},
#  {'max_time': 10000.0,
#   'alpha': 0.2,
#   'theta': array([0.15, 0.21, 1.  , 1.84, 1.34]),
#   'trial': 2},
#  {'max_time': 10000.0,
#   'alpha': 0.4,
#   'theta': array([0.53, 0.54, 0.73, 1.26, 0.94]),
#   'trial': 2},
#  {'max_time': 10000.0,
#   'alpha': 0.6,
#   'theta': array([0.86, 0.89, 0.6 , 1.53, 0.66]),
#   'trial': 2},
#  {'max_time': 10000.0,
#   'alpha': 0.8,
#   'theta': array([0.76, 0.79, 0.98, 1.42, 0.74]),
#   'trial': 2},
#  {'max_time': 10000.0,
#   'alpha': 0.2,
#   'theta': array([1.49e+00, 1.53e+00, 1.11e-01, 1.44e+00, 1.00e-16]),
#   'trial': 3},
#  {'max_time': 10000.0,
#   'alpha': 0.4,
#   'theta': array([1.  , 0.99, 0.44, 1.38, 0.51]),
#   'trial': 3},
#  {'max_time': 10000.0,
#   'alpha': 0.6,
#   'theta': array([0.8 , 0.74, 0.76, 1.31, 0.7 ]),
#   'trial': 3},
#  {'max_time': 10000.0,
#   'alpha': 0.8,
#   'theta': array([0.99, 0.99, 0.79, 1.3 , 0.52]),
#   'trial': 3},
#  {'max_time': 10000.0,
#   'alpha': 0.2,
#   'theta': array([0.62, 0.57, 0.35, 1.06, 0.87]),
#   'trial': 4},
#  {'max_time': 10000.0,
#   'alpha': 0.4,
#   'theta': array([0.9 , 0.88, 0.46, 1.54, 0.6 ]),
#   'trial': 4},
#  {'max_time': 10000.0,
#   'alpha': 0.6,
#   'theta': array([0.69, 0.72, 0.8 , 1.24, 0.79]),
#   'trial': 4},
#  {'max_time': 10000.0,
#   'alpha': 0.8,
#   'theta': array([1.09, 1.05, 0.77, 1.25, 0.41]),
#   'trial': 4},
#  {'max_time': 10000.0,
#   'alpha': 0.2,
#   'theta': array([0.55, 0.47, 0.5 , 0.95, 0.95]),
#   'trial': 5},
#  {'max_time': 10000.0,
#   'alpha': 0.4,
#   'theta': array([1.53e+00, 1.46e+00, 2.93e-01, 1.14e+00, 1.00e-16]),
#   'trial': 5},
#  {'max_time': 10000.0,
#   'alpha': 0.6,
#   'theta': array([0.92, 0.97, 0.63, 1.35, 0.57]),
#   'trial': 5},
#  {'max_time': 10000.0,
#   'alpha': 0.8,
#   'theta': array([0.88, 0.9 , 0.92, 1.34, 0.62]),
#   'trial': 5},
#  {'max_time': 10000.0,
#   'alpha': 0.2,
#   'theta': array([1.48e+00, 1.48e+00, 1.43e-01, 1.21e+00, 1.00e-16]),
#   'trial': 6},
#  {'max_time': 10000.0,
#   'alpha': 0.4,
#   'theta': array([1.50e+00, 1.56e+00, 2.37e-01, 1.36e+00, 1.00e-16]),
#   'trial': 6},
#  {'max_time': 10000.0,
#   'alpha': 0.6,
#   'theta': array([1.06, 0.96, 0.63, 1.16, 0.46]),
#   'trial': 6},
#  {'max_time': 10000.0,
#   'alpha': 0.8,
#   'theta': array([0.79, 0.76, 1.  , 1.4 , 0.72]),
#   'trial': 6}]
